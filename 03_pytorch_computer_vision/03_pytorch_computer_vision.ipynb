# %% [markdown]
# ## Computer vision libraries in PyTorch

# %%
# Import PyTorch
import torch
from torch import nn

# Import torchvision
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

# Import matplotlib for visualization
import matplotlib.pyplot as plt

# Check versions
print(f"PyTorch version: {torch.__version__}\ntorchvision version: {torchvision.__version__}")
# Out:
# PyTorch version: 2.0.1+cu117
# torchvision version: 0.15.2+cu117

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## Getting a dataset

# %%
# Setup training data
train_data = datasets.FashionMNIST(
    root="data", # where to download data to?
    train=True, # get training data
    download=True, # download data if it doesn't exist on disk
    transform=ToTensor(), # images come as PIL format, we want to turn into Torch tensors
    target_transform=None # you can transform labels as well
)

# Setup testing data
test_data = datasets.FashionMNIST(
    root="data",
    train=False, # get test data
    download=True,
    transform=ToTensor()
)

# %%
# See first training sample
image, label = train_data[0]
image, label
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#            0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#            0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#            0.0157, 0.0000, 0.0000, 0.0118],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#            0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0471, 0.0392, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#            0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#            0.3020, 0.5098, 0.2824, 0.0588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#            0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#            0.5529, 0.3451, 0.6745, 0.2588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#            0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#            0.4824, 0.7686, 0.8980, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#            0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#            0.8745, 0.9608, 0.6784, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#            0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#            0.8627, 0.9529, 0.7922, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#            0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#            0.8863, 0.7725, 0.8196, 0.2039],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#            0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#            0.9608, 0.4667, 0.6549, 0.2196],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#            0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#            0.8510, 0.8196, 0.3608, 0.0000],
#           [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#            0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#            0.8549, 1.0000, 0.3020, 0.0000],
#           [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#            0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#            0.8784, 0.9569, 0.6235, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#            0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#            0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#            0.9137, 0.9333, 0.8431, 0.0000],
#           [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#            0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#            0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#            0.8627, 0.9098, 0.9647, 0.0000],
#           [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#            0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#            0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#            0.8706, 0.8941, 0.8824, 0.0000],
#           [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#            0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#            0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#            0.8745, 0.8784, 0.8980, 0.1137],
#           [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#            0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#            0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#            0.8627, 0.8667, 0.9020, 0.2627],
#           [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#            0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#            0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#            0.7098, 0.8039, 0.8078, 0.4510],
#           [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#            0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#            0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#            0.6549, 0.6941, 0.8235, 0.3608],
#           [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#            0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#            0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#            0.7529, 0.8471, 0.6667, 0.0000],
#           [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#            0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#            0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#            0.3882, 0.2275, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#            0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  9)

# %% [markdown]
# ### - Input and output shapes of a computer vision model

# %%
# What's the shape of the image?
image.shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# [color_channels=1, height=28, width=28]

# %%
# How many samples are there?
len(train_data.data), len(train_data.targets), len(test_data.data), len(test_data.targets)
# Out:
# (60000, 60000, 10000, 10000)

# %%
# See classes
class_names = train_data.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %% [markdown]
# ### - Visualizing our data

# %%
image, label = train_data[0]
print(f"Image shape: {image.shape}")
plt.imshow(image.squeeze()) # image shape is [1, 28, 28] (colour channels, height, width)
plt.title(label)
# Out:
# Image shape: torch.Size([1, 28, 28])
# Text(0.5, 1.0, '9')

# %%
plt.imshow(image.squeeze(), cmap="gray")
plt.title(class_names[label])
# Out:
# Text(0.5, 1.0, 'Ankle boot')

# %%
# Plot more images
torch.manual_seed(42)
fig = plt.figure(figsize=(9, 9))
rows, cols = 4, 4
for i in range(1, rows * cols + 1):
    random_idx = torch.randint(0, len(train_data), size=[1]).item()
    img, label = train_data[random_idx]
    fig.add_subplot(rows, cols, i)
    plt.imshow(img.squeeze(), cmap="gray")
    plt.title(class_names[label])
    plt.axis(False)

# %% [markdown]
# ## Prepare DataLoader

# %%
from torch.utils.data import DataLoader

# Setup the batch size hyperparameter
BATCH_SIZE = 32

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data, # dataset to turn iterable
                              batch_size=BATCH_SIZE, # how many samples per batch?
                              shuffle=True) #shuffle data every epoch?

test_dataloader= DataLoader(test_data,
                            batch_size=BATCH_SIZE,
                            shuffle=False)

# Let's check out what we've created
print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x0000029A570119F0>, <torch.utils.data.dataloader.DataLoader object at 0x0000029A57011900>)
# Length of train dataloader: 1875 batches of 32
# Length of test dataloader: 313 batches of 32

# %%
# Check out what's inside the training dataloader
train_features_batch, train_labels_batch = next(iter(train_dataloader))
train_features_batch.shape, train_labels_batch.shape
# Out:
# (torch.Size([32, 1, 28, 28]), torch.Size([32]))

# %%
# Show a sample
torch.manual_seed(42)
random_idx = torch.randint(0, len(train_features_batch), size=[1]).item()
img, label = train_features_batch[random_idx], train_labels_batch[random_idx]
plt.imshow(img.squeeze(), cmap="gray")
plt.title(class_names[label])
plt.axis("off")
print(f"Image size: {img.shape}")
print(f"Label: {label}, label size: {label.shape}")
# Out:
# Image size: torch.Size([1, 28, 28])
# Label: 6, label size: torch.Size([])

# %% [markdown]
# ## Model 0: Build a baseline model

# %%
# Create a flatten layer
flatten_model = nn.Flatten() # all nn modules function as a model (can do a forward pass)

# Get a single sample
x = train_features_batch[0]

# Flatten teh sample
output = flatten_model(x) # perform forward pass

# Print out what happened
print(f"Shape before flattening: {x.shape} -> [color_channels, height, width]")
print(f"Shape after flattening: {output.shape} -> [color_channels, height*weight]")
# Out:
# Shape before flattening: torch.Size([1, 28, 28]) -> [color_channels, height, width]
# Shape after flattening: torch.Size([1, 784]) -> [color_channels, height*weight]

# %%
class FashionMNISTModelV0(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # neural networks like their inputs in vector form
            nn.Linear(in_features=input_shape, out_features=hidden_units), # in_feature = number of features in a data sample (784 pixels)
            nn.Linear(in_features=hidden_units, out_features=output_shape)
        )
    
    def forward(self, x):
        return self.layer_stack(x)

# %%
torch.manual_seed(42)

# Need to setup model with input parameters
model_0 = FashionMNISTModelV0(input_shape=784, # one for every pixel (28x28)
                              hidden_units=10, # how many units in the hidden layer
                              output_shape=len(class_names) # one for every class
)

model_0.to("cpu") # keep model on CPU to begin with
# Out:
# FashionMNISTModelV0(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=10, bias=True)
#     (2): Linear(in_features=10, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### - Setup loss, optimizer and evaluation metrics

# %%
# Import accuracy metric
from helper_functions import accuracy_fn # Note: could also use torchmetrics.Accuracy(task="multiclass", num_classes=len(class_name)).to(device)

# Setup loss function and optimizer
loss_fn = nn.CrossEntropyLoss() # this is also called "criterion"/"cost function" in some places
optimizer = torch.optim.SGD(model_0.parameters(), lr=0.1)

# %% [markdown]
# ### - Creating a function to time our experiments

# %%
from timeit import default_timer as timer

def print_train_time(start: float, end: float, device: torch.device = None):
    """
    Prints difference betweeen start and end time.

    Args:
        start (float): Start time of computation (preferred in timeit format).
        end (float): End time of computation.
        device ([type], optional): Device that compute is running on. Defaults to None.

    Returns:
        float: time between start and end in seconds (higher is longer).
    """
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

# %% [markdown]
# ### - Creating a training loop and training a model on bathes of data

# %%
len(train_dataloader)
# Out:
# 1875

# %%
# Import tqdm for progress bar
from tqdm.auto import tqdm

# Set the seed and start the timer
torch.manual_seed(42)
train_time_start_on_cpu = timer()

# Set the number of epochs (we'll keep this small for faster training times)
epochs = 3

# Create training and testing loop
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n------")
    ### Training
    train_loss = 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):
        model_0.train()
        # 1. Forward pass
        y_pred = model_0(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)
        train_loss += loss # accumulatively add up teh loss per epoch

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()
        
        # 5. Optimizer step
        optimizer.step()

        # Print out how many samples have been seen
        if batch % 400 == 0:
            print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    # Divide total loss by length of train dataloader (average loss per batch per epoch)
    train_loss /= len(train_dataloader)

    ### Testing
    test_loss, test_acc = 0, 0
    model_0.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:
            # 1. Forward pass
            test_pred = model_0(X)

            # 2. Calculate loss (accumatively)
            test_loss += loss_fn(test_pred, y) # accumatively add up the loss per epoch

            # 3. Calculate accuracy (preds need to be same as y_true)
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

        # Calculate on test metrics need to happen inside torch.inference_mode()
        # Divide total test loss by length of test dataloader (per batch)
        test_loss /= len(test_dataloader)

        # Divide total accuracy by lenght of test dataloader (per batch)
        test_acc /= len(test_dataloader)
    
    # Print out what's happening
    print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")

# Calculate training time
train_time_end_on_cpu = timer()
total_train_time_model_0 = print_train_time(start=train_time_start_on_cpu,
                                            end=train_time_end_on_cpu,
                                            device=str(next(model_0.parameters()).device))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# ------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.59039 | Test loss: 0.50954, Test acc: 82.04%
#
# Epoch: 1
# ------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.47633 | Test loss: 0.47989, Test acc: 83.20%
#
# Epoch: 2
# ------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.45503 | Test loss: 0.47664, Test acc: 83.43%
#
# Train time on cpu: 37.504 seconds

# %% [markdown]
# ## Make predictions and get Model 0 results

# %%
torch.manual_seed(42)

def eval_model(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               accuracy_fn):
    """
    Returning a dictionary containing the results of model predicting on data_loader.

    Args:
        model (torch.nn.Module): A PyTorch model capable of making predictions on data_loader.
        data_loader (torch.utils.data.DataLoader): The target dataset to predict on.
        loss_fn (torch.nn.Module): The loss function of model.
        accuracy_fn: An accuracy function to compare the models predictions to the truth labels.

    Returns:
        (dict): Results of model making predictions on data_loader.
    """
    loss, acc = 0, 0
    model.eval()
    with torch.inference_mode():
        for X, y in data_loader:
            # Make predictions with the model
            y_pred = model(X)

            # Accumulate the loss and accuracy values per batch
            loss += loss_fn(y_pred, y)
            acc += accuracy_fn(y_true=y, 
                               y_pred=y_pred.argmax(dim=1)) # For accuracy, need the prediction labels (logits -> pred_prob -> pred_labels)
        
        # Scale loss and acc to find the average loss/acc per batch
        loss /= len(data_loader)
        acc /= len(data_loader)

    return {"model_name": model.__class__.__name__, # only works when model was created with a class
            "model_loss": loss.item(),
            "model_acc": acc}

# Calculate model 0 results on test dataset
model_0_result = eval_model(model=model_0,
                            data_loader=test_dataloader,
                            loss_fn=loss_fn,
                            accuracy_fn=accuracy_fn)
model_0_result
# Out:
# {'model_name': 'FashionMNISTModelV0',
#  'model_loss': 0.4766390025615692,
#  'model_acc': 83.42651757188499}

# %% [markdown]
# ## Setup device agnostic-code (for using GPU if there is one)

# %%
# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## Model 1: Building a better model with non-linearity

# %%
# Creat a model with non-linear and linear layers
class FashionMNISTModelV1(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # flatten inputs into single vector
            nn.Linear(in_features=input_shape, out_features= hidden_units),
            nn.ReLU(),
            nn.Linear(in_features=hidden_units, out_features=output_shape),
            nn.ReLU()
        )

    def forward(self, x: torch.tensor):
        return self.layer_stack(x)

# %%
torch.manual_seed(42)

model_1 = FashionMNISTModelV1(input_shape=784, # number of input features
                              hidden_units=10,
                              output_shape=len(class_names)).to(device) # number of output classes desired

next(model_1.parameters()).device # check model device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ### - Setup loss, optimizer and evaluation metrics

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model_1.parameters(),
                            lr=0.1)

# %% [markdown]
# ### - Functionizing training and testing

# %%
def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):
    train_loss, train_acc = 0, 0
    model.to(device)
    model.train()
    for batch, (X, y) in enumerate(data_loader):
        # Send data to GPU
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss
        train_acc += accuracy_fn(y_true=y,
                                 y_pred=y_pred.argmax(dim=1))
        
        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

    # Calculate loss and accuracy per epoch and print out what's happening
    train_loss /= len(data_loader)
    train_acc /= len(data_loader)
    print(f"Train loss: {train_loss:.5f} | Train accuracy: {train_acc:.2f}%")

def test_step(data_loader: torch.utils.data.DataLoader,
              model: torch.nn.Module,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):
    test_loss, test_acc = 0, 0
    model.to(device)
    model.eval() # Put model in eval mode
    # Trun on inference context manager
    with torch.inference_mode():
        for X, y in data_loader:
            # Send data to GPU
            X, y = X.to(device), y.to(device)

            # 1. Forward pass
            test_pred = model(X)

            # 2. Calculate loss and accuracy
            test_loss += loss_fn(test_pred, y)
            test_acc += accuracy_fn(y_true=y,
                                    y_pred=test_pred.argmax(dim=1))
            
        # Adjust metrics and print out
        test_loss /= len(data_loader)
        test_acc /= len(data_loader)
        print(f"Test loss:{test_loss:.5f} | Test accuracy: {test_acc:.2f}%\n")

# %%
torch.manual_seed(42)

# Measure time
from timeit import default_timer as timer
train_time_start_on_gpu = timer()

epochs = 3
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n----------")
    train_step(model=model_1,
               data_loader=train_dataloader,
               loss_fn=loss_fn,
               optimizer=optimizer,
               accuracy_fn=accuracy_fn)
    test_step(data_loader=test_dataloader,
              model=model_1,
              loss_fn=loss_fn,
              accuracy_fn=accuracy_fn)
    
train_time_end_on_gpu = timer()
total_train_time_model_1 = print_train_time(start=train_time_start_on_cpu,
                                            end=train_time_end_on_gpu,
                                            device=device)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# ----------
# Train loss: 1.09199 | Train accuracy: 61.34%
# Test loss:0.00306 | Test accuracy: 0.22%
#
# Test loss:0.00278 | Test accuracy: 0.21%
#
# Test loss:0.00261 | Test accuracy: 0.21%
#
# Test loss:0.00220 | Test accuracy: 0.24%
#
# Test loss:0.00204 | Test accuracy: 0.25%
#
# Test loss:0.00254 | Test accuracy: 0.21%
#
# Test loss:0.00241 | Test accuracy: 0.23%
#
# Test loss:0.00335 | Test accuracy: 0.20%
#
# Test loss:0.00262 | Test accuracy: 0.21%
#
# Test loss:0.00309 | Test accuracy: 0.23%
#
# Test loss:0.00293 | Test accuracy: 0.18%
#
# Test loss:0.00291 | Test accuracy: 0.22%
#
# Test loss:0.00222 | Test accuracy: 0.24%
#
# Test loss:0.00216 | Test accuracy: 0.24%
#
# Test loss:0.00408 | Test accuracy: 0.18%
#
# Test loss:0.00288 | Test accuracy: 0.22%
#
# Test loss:0.00292 | Test accuracy: 0.20%
#
# Test loss:0.00313 | Test accuracy: 0.20%
#
# Test loss:0.00333 | Test accuracy: 0.20%
#
# Test loss:0.00337 | Test accuracy: 0.19%
#
# Test loss:0.00206 | Test accuracy: 0.25%
#
# Test loss:0.00338 | Test accuracy: 0.21%
#
# Test loss:0.00325 | Test accuracy: 0.24%
#
# Test loss:0.00278 | Test accuracy: 0.22%
#
# Test loss:0.00220 | Test accuracy: 0.24%
#
# Test loss:0.00278 | Test accuracy: 0.23%
#
# Test loss:0.00262 | Test accuracy: 0.22%
#
# Test loss:0.00280 | Test accuracy: 0.23%
#
# Test loss:0.00254 | Test accuracy: 0.20%
#
# Test loss:0.00198 | Test accuracy: 0.25%
#
# Test loss:0.00465 | Test accuracy: 0.17%
#
# Test loss:0.00390 | Test accuracy: 0.15%
#
# Test loss:0.00286 | Test accuracy: 0.21%
#
# Test loss:0.00253 | Test accuracy: 0.23%
#
# Test loss:0.00321 | Test accuracy: 0.20%
#
# Test loss:0.00299 | Test accuracy: 0.18%
#
# Test loss:0.00246 | Test accuracy: 0.24%
#
# Test loss:0.00288 | Test accuracy: 0.20%
#
# Test loss:0.00325 | Test accuracy: 0.20%
#
# Test loss:0.00244 | Test accuracy: 0.25%
#
# Test loss:0.00276 | Test accuracy: 0.23%
#
# Test loss:0.00324 | Test accuracy: 0.23%
#
# Test loss:0.00247 | Test accuracy: 0.24%
#
# Test loss:0.00242 | Test accuracy: 0.23%
#
# Test loss:0.00210 | Test accuracy: 0.24%
#
# Test loss:0.00278 | Test accuracy: 0.22%
#
# Test loss:0.00328 | Test accuracy: 0.18%
#
# Test loss:0.00327 | Test accuracy: 0.20%
#
# Test loss:0.00286 | Test accuracy: 0.21%
#
# Test loss:0.00256 | Test accuracy: 0.24%
#
# Test loss:0.00335 | Test accuracy: 0.18%
#
# Test loss:0.00318 | Test accuracy: 0.20%
#
# Test loss:0.00253 | Test accuracy: 0.25%
#
# Test loss:0.00369 | Test accuracy: 0.18%
#
# Test loss:0.00309 | Test accuracy: 0.21%
#
# Test loss:0.00238 | Test accuracy: 0.22%
#
# Test loss:0.00410 | Test accuracy: 0.19%
#
# Test loss:0.00366 | Test accuracy: 0.18%
#
# Test loss:0.00182 | Test accuracy: 0.25%
#
# Test loss:0.00247 | Test accuracy: 0.24%
#
# Test loss:0.00208 | Test accuracy: 0.26%
#
# Test loss:0.00413 | Test accuracy: 0.16%
#
# Test loss:0.00337 | Test accuracy: 0.20%
#
# Test loss:0.00380 | Test accuracy: 0.18%
#
# Test loss:0.00414 | Test accuracy: 0.15%
#
# Test loss:0.00265 | Test accuracy: 0.24%
#
# Test loss:0.00254 | Test accuracy: 0.23%
#
# Test loss:0.00316 | Test accuracy: 0.21%
#
# Test loss:0.00451 | Test accuracy: 0.14%
#
# Test loss:0.00227 | Test accuracy: 0.25%
#
# Test loss:0.00252 | Test accuracy: 0.23%
#
# Test loss:0.00263 | Test accuracy: 0.20%
#
# Test loss:0.00346 | Test accuracy: 0.19%
#
# Test loss:0.00307 | Test accuracy: 0.18%
#
# Test loss:0.00312 | Test accuracy: 0.21%
#
# Test loss:0.00263 | Test accuracy: 0.22%
#
# Test loss:0.00296 | Test accuracy: 0.20%
#
# Test loss:0.00321 | Test accuracy: 0.19%
#
# Test loss:0.00383 | Test accuracy: 0.19%
#
# Test loss:0.00318 | Test accuracy: 0.20%
#
# Test loss:0.00229 | Test accuracy: 0.23%
#
# Test loss:0.00259 | Test accuracy: 0.26%
#
# Test loss:0.00276 | Test accuracy: 0.23%
#
# Test loss:0.00332 | Test accuracy: 0.21%
#
# Test loss:0.00287 | Test accuracy: 0.23%
#
# Test loss:0.00295 | Test accuracy: 0.21%
#
# Test loss:0.00290 | Test accuracy: 0.21%
#
# Test loss:0.00261 | Test accuracy: 0.24%
#
# Test loss:0.00323 | Test accuracy: 0.19%
#
# Test loss:0.00322 | Test accuracy: 0.23%
#
# Test loss:0.00413 | Test accuracy: 0.19%
#
# Test loss:0.00340 | Test accuracy: 0.19%
#
# Test loss:0.00242 | Test accuracy: 0.22%
#
# Test loss:0.00302 | Test accuracy: 0.22%
#
# Test loss:0.00331 | Test accuracy: 0.19%
#
# Test loss:0.00315 | Test accuracy: 0.21%
#
# Test loss:0.00277 | Test accuracy: 0.21%
#
# Test loss:0.00321 | Test accuracy: 0.24%
#
# Test loss:0.00209 | Test accuracy: 0.25%
#
# Test loss:0.00311 | Test accuracy: 0.22%
#
# Test loss:0.00301 | Test accuracy: 0.23%
#
# Test loss:0.00427 | Test accuracy: 0.19%
#
# Test loss:0.00286 | Test accuracy: 0.23%
#
# Test loss:0.00424 | Test accuracy: 0.17%
#
# Test loss:0.00262 | Test accuracy: 0.23%
#
# Test loss:0.00214 | Test accuracy: 0.24%
#
# Test loss:0.00329 | Test accuracy: 0.19%
#
# Test loss:0.00249 | Test accuracy: 0.23%
#
# Test loss:0.00415 | Test accuracy: 0.18%
#
# Test loss:0.00302 | Test accuracy: 0.20%
#
# Test loss:0.00310 | Test accuracy: 0.21%
#
# Test loss:0.00237 | Test accuracy: 0.24%
#
# Test loss:0.00300 | Test accuracy: 0.20%
#
# Test loss:0.00296 | Test accuracy: 0.24%
#
# Test loss:0.00384 | Test accuracy: 0.16%
#
# Test loss:0.00391 | Test accuracy: 0.20%
#
# Test loss:0.00319 | Test accuracy: 0.19%
#
# Test loss:0.00249 | Test accuracy: 0.22%
#
# Test loss:0.00365 | Test accuracy: 0.18%
#
# Test loss:0.00375 | Test accuracy: 0.20%
#
# Test loss:0.00261 | Test accuracy: 0.22%
#
# Test loss:0.00239 | Test accuracy: 0.24%
#
# Test loss:0.00374 | Test accuracy: 0.18%
#
# Test loss:0.00362 | Test accuracy: 0.20%
#
# Test loss:0.00334 | Test accuracy: 0.21%
#
# Test loss:0.00296 | Test accuracy: 0.20%
#
# Test loss:0.00364 | Test accuracy: 0.20%
#
# Test loss:0.00431 | Test accuracy: 0.17%
#
# Test loss:0.00178 | Test accuracy: 0.25%
#
# Test loss:0.00500 | Test accuracy: 0.16%
#
# Test loss:0.00275 | Test accuracy: 0.22%
#
# Test loss:0.00258 | Test accuracy: 0.22%
#
# Test loss:0.00244 | Test accuracy: 0.23%
#
# Test loss:0.00297 | Test accuracy: 0.23%
#
# Test loss:0.00281 | Test accuracy: 0.23%
#
# Test loss:0.00244 | Test accuracy: 0.23%
#
# Test loss:0.00229 | Test accuracy: 0.23%
#
# Test loss:0.00351 | Test accuracy: 0.20%
#
# Test loss:0.00287 | Test accuracy: 0.20%
#
# Test loss:0.00246 | Test accuracy: 0.21%
#
# Test loss:0.00334 | Test accuracy: 0.19%
#
# Test loss:0.00138 | Test accuracy: 0.27%
#
# Test loss:0.00261 | Test accuracy: 0.23%
#
# Test loss:0.00214 | Test accuracy: 0.23%
#
# Test loss:0.00298 | Test accuracy: 0.21%
#
# Test loss:0.00335 | Test accuracy: 0.19%
#
# Test loss:0.00456 | Test accuracy: 0.16%
#
# Test loss:0.00250 | Test accuracy: 0.25%
#
# Test loss:0.00399 | Test accuracy: 0.17%
#
# Test loss:0.00195 | Test accuracy: 0.24%
#
# Test loss:0.00489 | Test accuracy: 0.16%
#
# Test loss:0.00351 | Test accuracy: 0.19%
#
# Test loss:0.00288 | Test accuracy: 0.19%
#
# Test loss:0.00399 | Test accuracy: 0.18%
#
# Test loss:0.00429 | Test accuracy: 0.17%
#
# Test loss:0.00258 | Test accuracy: 0.22%
#
# Test loss:0.00390 | Test accuracy: 0.17%
#
# Test loss:0.00281 | Test accuracy: 0.21%
#
# Test loss:0.00439 | Test accuracy: 0.15%
#
# Test loss:0.00358 | Test accuracy: 0.16%
#
# Test loss:0.00301 | Test accuracy: 0.24%
#
# Test loss:0.00372 | Test accuracy: 0.18%
#
# Test loss:0.00354 | Test accuracy: 0.20%
#
# Test loss:0.00204 | Test accuracy: 0.25%
#
# Test loss:0.00344 | Test accuracy: 0.21%
#
# Test loss:0.00297 | Test accuracy: 0.20%
#
# Test loss:0.00364 | Test accuracy: 0.21%
#
# Test loss:0.00208 | Test accuracy: 0.24%
#
# Test loss:0.00273 | Test accuracy: 0.20%
#
# Test loss:0.00385 | Test accuracy: 0.15%
#
# Test loss:0.00313 | Test accuracy: 0.22%
#
# Test loss:0.00309 | Test accuracy: 0.21%
#
# Test loss:0.00467 | Test accuracy: 0.17%
#
# Test loss:0.00332 | Test accuracy: 0.20%
#
# Test loss:0.00433 | Test accuracy: 0.18%
#
# Test loss:0.00346 | Test accuracy: 0.20%
#
# Test loss:0.00284 | Test accuracy: 0.19%
#
# Test loss:0.00453 | Test accuracy: 0.13%
#
# Test loss:0.00317 | Test accuracy: 0.21%
#
# Test loss:0.00341 | Test accuracy: 0.20%
#
# Test loss:0.00369 | Test accuracy: 0.18%
#
# Test loss:0.00317 | Test accuracy: 0.21%
#
# Test loss:0.00301 | Test accuracy: 0.22%
#
# Test loss:0.00157 | Test accuracy: 0.25%
#
# Test loss:0.00254 | Test accuracy: 0.24%
#
# Test loss:0.00298 | Test accuracy: 0.21%
#
# Test loss:0.00372 | Test accuracy: 0.16%
#
# Test loss:0.00304 | Test accuracy: 0.19%
#
# Test loss:0.00356 | Test accuracy: 0.18%
#
# Test loss:0.00273 | Test accuracy: 0.23%
#
# Test loss:0.00287 | Test accuracy: 0.19%
#
# Test loss:0.00308 | Test accuracy: 0.21%
#
# Test loss:0.00383 | Test accuracy: 0.16%
#
# Test loss:0.00391 | Test accuracy: 0.17%
#
# Test loss:0.00306 | Test accuracy: 0.19%
#
# Test loss:0.00288 | Test accuracy: 0.20%
#
# Test loss:0.00347 | Test accuracy: 0.20%
#
# Test loss:0.00337 | Test accuracy: 0.19%
#
# Test loss:0.00340 | Test accuracy: 0.20%
#
# Test loss:0.00277 | Test accuracy: 0.20%
#
# Test loss:0.00308 | Test accuracy: 0.20%
#
# Test loss:0.00282 | Test accuracy: 0.22%
#
# Test loss:0.00259 | Test accuracy: 0.23%
#
# Test loss:0.00207 | Test accuracy: 0.23%
#
# Test loss:0.00284 | Test accuracy: 0.21%
#
# Test loss:0.00307 | Test accuracy: 0.19%
#
# Test loss:0.00274 | Test accuracy: 0.26%
#
# Test loss:0.00396 | Test accuracy: 0.19%
#
# Test loss:0.00427 | Test accuracy: 0.17%
#
# Test loss:0.00409 | Test accuracy: 0.18%
#
# Test loss:0.00333 | Test accuracy: 0.18%
#
# Test loss:0.00286 | Test accuracy: 0.22%
#
# Test loss:0.00293 | Test accuracy: 0.19%
#
# Test loss:0.00311 | Test accuracy: 0.18%
#
# Test loss:0.00330 | Test accuracy: 0.21%
#
# Test loss:0.00392 | Test accuracy: 0.17%
#
# Test loss:0.00267 | Test accuracy: 0.20%
#
# Test loss:0.00235 | Test accuracy: 0.24%
#
# Test loss:0.00292 | Test accuracy: 0.23%
#
# Test loss:0.00354 | Test accuracy: 0.18%
#
# Test loss:0.00260 | Test accuracy: 0.23%
#
# Test loss:0.00365 | Test accuracy: 0.19%
#
# Test loss:0.00263 | Test accuracy: 0.22%
#
# Test loss:0.00340 | Test accuracy: 0.18%
#
# Test loss:0.00361 | Test accuracy: 0.20%
#
# Test loss:0.00285 | Test accuracy: 0.20%
#
# Test loss:0.00284 | Test accuracy: 0.22%
#
# Test loss:0.00290 | Test accuracy: 0.21%
#
# Test loss:0.00331 | Test accuracy: 0.17%
#
# Test loss:0.00405 | Test accuracy: 0.17%
#
# Test loss:0.00407 | Test accuracy: 0.18%
#
# Test loss:0.00252 | Test accuracy: 0.23%
#
# Test loss:0.00311 | Test accuracy: 0.21%
#
# Test loss:0.00210 | Test accuracy: 0.24%
#
# Test loss:0.00360 | Test accuracy: 0.18%
#
# Test loss:0.00419 | Test accuracy: 0.18%
#
# Test loss:0.00347 | Test accuracy: 0.20%
#
# Test loss:0.00398 | Test accuracy: 0.19%
#
# Test loss:0.00346 | Test accuracy: 0.20%
#
# Test loss:0.00353 | Test accuracy: 0.18%
#
# Test loss:0.00226 | Test accuracy: 0.23%
#
# Test loss:0.00329 | Test accuracy: 0.21%
#
# Test loss:0.00195 | Test accuracy: 0.26%
#
# Test loss:0.00224 | Test accuracy: 0.24%
#
# Test loss:0.00445 | Test accuracy: 0.16%
#
# Test loss:0.00317 | Test accuracy: 0.19%
#
# Test loss:0.00411 | Test accuracy: 0.17%
#
# Test loss:0.00234 | Test accuracy: 0.26%
#
# Test loss:0.00317 | Test accuracy: 0.22%
#
# Test loss:0.00295 | Test accuracy: 0.22%
#
# Test loss:0.00337 | Test accuracy: 0.20%
#
# Test loss:0.00291 | Test accuracy: 0.21%
#
# Test loss:0.00350 | Test accuracy: 0.17%
#
# Test loss:0.00310 | Test accuracy: 0.19%
#
# Test loss:0.00357 | Test accuracy: 0.20%
#
# Test loss:0.00230 | Test accuracy: 0.24%
#
# Test loss:0.00339 | Test accuracy: 0.23%
#
# Test loss:0.00232 | Test accuracy: 0.26%
#
# Test loss:0.00261 | Test accuracy: 0.23%
#
# Test loss:0.00360 | Test accuracy: 0.17%
#
# Test loss:0.00232 | Test accuracy: 0.25%
#
# Test loss:0.00208 | Test accuracy: 0.25%
#
# Test loss:0.00329 | Test accuracy: 0.20%
#
# Test loss:0.00253 | Test accuracy: 0.21%
#
# Test loss:0.00305 | Test accuracy: 0.20%
#
# Test loss:0.00293 | Test accuracy: 0.21%
#
# Test loss:0.00223 | Test accuracy: 0.23%
#
# Test loss:0.00237 | Test accuracy: 0.25%
#
# Test loss:0.00363 | Test accuracy: 0.19%
#
# Test loss:0.00267 | Test accuracy: 0.21%
#
# Test loss:0.00218 | Test accuracy: 0.25%
#
# Test loss:0.00218 | Test accuracy: 0.23%
#
# Test loss:0.00393 | Test accuracy: 0.16%
#
# Test loss:0.00425 | Test accuracy: 0.17%
#
# Test loss:0.00357 | Test accuracy: 0.18%
#
# Test loss:0.00209 | Test accuracy: 0.25%
#
# Test loss:0.00272 | Test accuracy: 0.21%
#
# Test loss:0.00278 | Test accuracy: 0.21%
#
# Test loss:0.00385 | Test accuracy: 0.18%
#
# Test loss:0.00353 | Test accuracy: 0.17%
#
# Test loss:0.00284 | Test accuracy: 0.22%
#
# Test loss:0.00238 | Test accuracy: 0.25%
#
# Test loss:0.00244 | Test accuracy: 0.21%
#
# Test loss:0.00287 | Test accuracy: 0.21%
#
# Test loss:0.00290 | Test accuracy: 0.19%
#
# Test loss:0.00429 | Test accuracy: 0.16%
#
# Test loss:0.00407 | Test accuracy: 0.16%
#
# Test loss:0.00300 | Test accuracy: 0.22%
#
# Test loss:0.00313 | Test accuracy: 0.18%
#
# Test loss:0.00372 | Test accuracy: 0.20%
#
# Test loss:0.00288 | Test accuracy: 0.20%
#
# Test loss:0.00312 | Test accuracy: 0.21%
#
# Test loss:0.00339 | Test accuracy: 0.17%
#
# Test loss:0.00298 | Test accuracy: 0.20%
#
# Test loss:0.00192 | Test accuracy: 0.24%
#
# Test loss:0.00306 | Test accuracy: 0.19%
#
# Test loss:0.00364 | Test accuracy: 0.21%
#
# Test loss:0.00359 | Test accuracy: 0.20%
#
# Test loss:0.00316 | Test accuracy: 0.23%
#
# Test loss:0.00254 | Test accuracy: 0.23%
#
# Test loss:0.00298 | Test accuracy: 0.21%
#
# Test loss:0.00287 | Test accuracy: 0.22%
#
# Test loss:0.00319 | Test accuracy: 0.19%
#
# Test loss:0.00159 | Test accuracy: 0.27%
#
# Test loss:0.00229 | Test accuracy: 0.25%
#
# Test loss:0.00181 | Test accuracy: 0.25%
#
# Test loss:0.00317 | Test accuracy: 0.21%
#
# Test loss:0.00196 | Test accuracy: 0.23%
#
# Test loss:0.00337 | Test accuracy: 0.23%
#
# Test loss:0.00297 | Test accuracy: 0.21%
#
# Test loss:0.00357 | Test accuracy: 0.20%
#
# Test loss:0.00357 | Test accuracy: 0.18%
#
# Test loss:0.00220 | Test accuracy: 0.24%
#
# Epoch: 1
# ----------
# Train loss: 0.78101 | Train accuracy: 71.93%
# Test loss:0.00239 | Test accuracy: 0.23%
#
# Test loss:0.00206 | Test accuracy: 0.24%
#
# Test loss:0.00203 | Test accuracy: 0.25%
#
# Test loss:0.00162 | Test accuracy: 0.28%
#
# Test loss:0.00148 | Test accuracy: 0.27%
#
# Test loss:0.00139 | Test accuracy: 0.26%
#
# Test loss:0.00160 | Test accuracy: 0.27%
#
# Test loss:0.00241 | Test accuracy: 0.22%
#
# Test loss:0.00253 | Test accuracy: 0.22%
#
# Test loss:0.00240 | Test accuracy: 0.27%
#
# Test loss:0.00216 | Test accuracy: 0.23%
#
# Test loss:0.00261 | Test accuracy: 0.23%
#
# Test loss:0.00165 | Test accuracy: 0.25%
#
# Test loss:0.00184 | Test accuracy: 0.25%
#
# Test loss:0.00334 | Test accuracy: 0.22%
#
# Test loss:0.00183 | Test accuracy: 0.26%
#
# Test loss:0.00201 | Test accuracy: 0.23%
#
# Test loss:0.00221 | Test accuracy: 0.22%
#
# Test loss:0.00203 | Test accuracy: 0.25%
#
# Test loss:0.00272 | Test accuracy: 0.24%
#
# Test loss:0.00189 | Test accuracy: 0.27%
#
# Test loss:0.00281 | Test accuracy: 0.22%
#
# Test loss:0.00231 | Test accuracy: 0.24%
#
# Test loss:0.00230 | Test accuracy: 0.24%
#
# Test loss:0.00107 | Test accuracy: 0.29%
#
# Test loss:0.00211 | Test accuracy: 0.23%
#
# Test loss:0.00176 | Test accuracy: 0.25%
#
# Test loss:0.00214 | Test accuracy: 0.26%
#
# Test loss:0.00226 | Test accuracy: 0.23%
#
# Test loss:0.00155 | Test accuracy: 0.26%
#
# Test loss:0.00342 | Test accuracy: 0.21%
#
# Test loss:0.00268 | Test accuracy: 0.20%
#
# Test loss:0.00224 | Test accuracy: 0.23%
#
# Test loss:0.00170 | Test accuracy: 0.25%
#
# Test loss:0.00241 | Test accuracy: 0.24%
#
# Test loss:0.00177 | Test accuracy: 0.25%
#
# Test loss:0.00185 | Test accuracy: 0.27%
#
# Test loss:0.00143 | Test accuracy: 0.28%
#
# Test loss:0.00250 | Test accuracy: 0.23%
#
# Test loss:0.00176 | Test accuracy: 0.28%
#
# Test loss:0.00290 | Test accuracy: 0.23%
#
# Test loss:0.00279 | Test accuracy: 0.24%
#
# Test loss:0.00186 | Test accuracy: 0.25%
#
# Test loss:0.00226 | Test accuracy: 0.24%
#
# Test loss:0.00100 | Test accuracy: 0.28%
#
# Test loss:0.00234 | Test accuracy: 0.24%
#
# Test loss:0.00283 | Test accuracy: 0.19%
#
# Test loss:0.00237 | Test accuracy: 0.26%
#
# Test loss:0.00168 | Test accuracy: 0.26%
#
# Test loss:0.00195 | Test accuracy: 0.25%
#
# Test loss:0.00278 | Test accuracy: 0.21%
#
# Test loss:0.00241 | Test accuracy: 0.22%
#
# Test loss:0.00206 | Test accuracy: 0.25%
#
# Test loss:0.00186 | Test accuracy: 0.25%
#
# Test loss:0.00225 | Test accuracy: 0.26%
#
# Test loss:0.00157 | Test accuracy: 0.27%
#
# Test loss:0.00259 | Test accuracy: 0.25%
#
# Test loss:0.00317 | Test accuracy: 0.21%
#
# Test loss:0.00118 | Test accuracy: 0.28%
#
# Test loss:0.00136 | Test accuracy: 0.26%
#
# Test loss:0.00191 | Test accuracy: 0.27%
#
# Test loss:0.00356 | Test accuracy: 0.19%
#
# Test loss:0.00241 | Test accuracy: 0.23%
#
# Test loss:0.00298 | Test accuracy: 0.21%
#
# Test loss:0.00307 | Test accuracy: 0.21%
#
# Test loss:0.00172 | Test accuracy: 0.27%
#
# Test loss:0.00172 | Test accuracy: 0.25%
#
# Test loss:0.00244 | Test accuracy: 0.24%
#
# Test loss:0.00302 | Test accuracy: 0.19%
#
# Test loss:0.00138 | Test accuracy: 0.27%
#
# Test loss:0.00156 | Test accuracy: 0.26%
#
# Test loss:0.00179 | Test accuracy: 0.23%
#
# Test loss:0.00290 | Test accuracy: 0.22%
#
# Test loss:0.00253 | Test accuracy: 0.23%
#
# Test loss:0.00238 | Test accuracy: 0.23%
#
# Test loss:0.00229 | Test accuracy: 0.23%
#
# Test loss:0.00173 | Test accuracy: 0.27%
#
# Test loss:0.00241 | Test accuracy: 0.22%
#
# Test loss:0.00316 | Test accuracy: 0.20%
#
# Test loss:0.00190 | Test accuracy: 0.26%
#
# Test loss:0.00157 | Test accuracy: 0.29%
#
# Test loss:0.00207 | Test accuracy: 0.26%
#
# Test loss:0.00241 | Test accuracy: 0.24%
#
# Test loss:0.00248 | Test accuracy: 0.24%
#
# Test loss:0.00241 | Test accuracy: 0.25%
#
# Test loss:0.00283 | Test accuracy: 0.23%
#
# Test loss:0.00210 | Test accuracy: 0.24%
#
# Test loss:0.00210 | Test accuracy: 0.24%
#
# Test loss:0.00278 | Test accuracy: 0.18%
#
# Test loss:0.00286 | Test accuracy: 0.21%
#
# Test loss:0.00399 | Test accuracy: 0.19%
#
# Test loss:0.00280 | Test accuracy: 0.22%
#
# Test loss:0.00156 | Test accuracy: 0.27%
#
# Test loss:0.00237 | Test accuracy: 0.24%
#
# Test loss:0.00272 | Test accuracy: 0.22%
#
# Test loss:0.00286 | Test accuracy: 0.23%
#
# Test loss:0.00253 | Test accuracy: 0.21%
#
# Test loss:0.00267 | Test accuracy: 0.25%
#
# Test loss:0.00173 | Test accuracy: 0.26%
#
# Test loss:0.00240 | Test accuracy: 0.24%
#
# Test loss:0.00217 | Test accuracy: 0.26%
#
# Test loss:0.00343 | Test accuracy: 0.21%
#
# Test loss:0.00258 | Test accuracy: 0.20%
#
# Test loss:0.00273 | Test accuracy: 0.24%
#
# Test loss:0.00219 | Test accuracy: 0.21%
#
# Test loss:0.00120 | Test accuracy: 0.27%
#
# Test loss:0.00218 | Test accuracy: 0.23%
#
# Test loss:0.00244 | Test accuracy: 0.22%
#
# Test loss:0.00415 | Test accuracy: 0.20%
#
# Test loss:0.00199 | Test accuracy: 0.24%
#
# Test loss:0.00268 | Test accuracy: 0.24%
#
# Test loss:0.00200 | Test accuracy: 0.26%
#
# Test loss:0.00241 | Test accuracy: 0.24%
#
# Test loss:0.00151 | Test accuracy: 0.27%
#
# Test loss:0.00237 | Test accuracy: 0.24%
#
# Test loss:0.00255 | Test accuracy: 0.23%
#
# Test loss:0.00215 | Test accuracy: 0.26%
#
# Test loss:0.00210 | Test accuracy: 0.24%
#
# Test loss:0.00245 | Test accuracy: 0.23%
#
# Test loss:0.00257 | Test accuracy: 0.23%
#
# Test loss:0.00224 | Test accuracy: 0.24%
#
# Test loss:0.00192 | Test accuracy: 0.24%
#
# Test loss:0.00328 | Test accuracy: 0.19%
#
# Test loss:0.00353 | Test accuracy: 0.21%
#
# Test loss:0.00254 | Test accuracy: 0.25%
#
# Test loss:0.00217 | Test accuracy: 0.24%
#
# Test loss:0.00330 | Test accuracy: 0.23%
#
# Test loss:0.00314 | Test accuracy: 0.22%
#
# Test loss:0.00130 | Test accuracy: 0.27%
#
# Test loss:0.00430 | Test accuracy: 0.18%
#
# Test loss:0.00202 | Test accuracy: 0.24%
#
# Test loss:0.00253 | Test accuracy: 0.21%
#
# Test loss:0.00225 | Test accuracy: 0.22%
#
# Test loss:0.00159 | Test accuracy: 0.28%
#
# Test loss:0.00254 | Test accuracy: 0.23%
#
# Test loss:0.00137 | Test accuracy: 0.28%
#
# Test loss:0.00165 | Test accuracy: 0.26%
#
# Test loss:0.00264 | Test accuracy: 0.22%
#
# Test loss:0.00194 | Test accuracy: 0.25%
#
# Test loss:0.00173 | Test accuracy: 0.24%
#
# Test loss:0.00267 | Test accuracy: 0.21%
#
# Test loss:0.00077 | Test accuracy: 0.30%
#
# Test loss:0.00190 | Test accuracy: 0.26%
#
# Test loss:0.00160 | Test accuracy: 0.27%
#
# Test loss:0.00250 | Test accuracy: 0.22%
#
# Test loss:0.00309 | Test accuracy: 0.20%
#
# Test loss:0.00358 | Test accuracy: 0.18%
#
# Test loss:0.00217 | Test accuracy: 0.24%
#
# Test loss:0.00327 | Test accuracy: 0.19%
#
# Test loss:0.00178 | Test accuracy: 0.26%
#
# Test loss:0.00361 | Test accuracy: 0.22%
#
# Test loss:0.00243 | Test accuracy: 0.23%
#
# Test loss:0.00196 | Test accuracy: 0.23%
#
# Test loss:0.00280 | Test accuracy: 0.20%
#
# Test loss:0.00330 | Test accuracy: 0.20%
#
# Test loss:0.00221 | Test accuracy: 0.23%
#
# Test loss:0.00313 | Test accuracy: 0.21%
#
# Test loss:0.00292 | Test accuracy: 0.21%
#
# Test loss:0.00378 | Test accuracy: 0.17%
#
# Test loss:0.00216 | Test accuracy: 0.25%
#
# Test loss:0.00265 | Test accuracy: 0.25%
#
# Test loss:0.00294 | Test accuracy: 0.23%
#
# Test loss:0.00308 | Test accuracy: 0.22%
#
# Test loss:0.00151 | Test accuracy: 0.27%
#
# Test loss:0.00342 | Test accuracy: 0.22%
#
# Test loss:0.00217 | Test accuracy: 0.22%
#
# Test loss:0.00229 | Test accuracy: 0.25%
#
# Test loss:0.00144 | Test accuracy: 0.25%
#
# Test loss:0.00158 | Test accuracy: 0.27%
#
# Test loss:0.00222 | Test accuracy: 0.23%
#
# Test loss:0.00218 | Test accuracy: 0.25%
#
# Test loss:0.00187 | Test accuracy: 0.24%
#
# Test loss:0.00412 | Test accuracy: 0.19%
#
# Test loss:0.00224 | Test accuracy: 0.24%
#
# Test loss:0.00410 | Test accuracy: 0.20%
#
# Test loss:0.00299 | Test accuracy: 0.22%
#
# Test loss:0.00270 | Test accuracy: 0.19%
#
# Test loss:0.00347 | Test accuracy: 0.17%
#
# Test loss:0.00214 | Test accuracy: 0.24%
#
# Test loss:0.00228 | Test accuracy: 0.25%
#
# Test loss:0.00255 | Test accuracy: 0.24%
#
# Test loss:0.00239 | Test accuracy: 0.24%
#
# Test loss:0.00220 | Test accuracy: 0.25%
#
# Test loss:0.00093 | Test accuracy: 0.29%
#
# Test loss:0.00170 | Test accuracy: 0.25%
#
# Test loss:0.00282 | Test accuracy: 0.22%
#
# Test loss:0.00279 | Test accuracy: 0.19%
#
# Test loss:0.00213 | Test accuracy: 0.24%
#
# Test loss:0.00204 | Test accuracy: 0.23%
#
# Test loss:0.00161 | Test accuracy: 0.26%
#
# Test loss:0.00258 | Test accuracy: 0.23%
#
# Test loss:0.00206 | Test accuracy: 0.25%
#
# Test loss:0.00277 | Test accuracy: 0.21%
#
# Test loss:0.00264 | Test accuracy: 0.22%
#
# Test loss:0.00190 | Test accuracy: 0.24%
#
# Test loss:0.00216 | Test accuracy: 0.22%
#
# Test loss:0.00294 | Test accuracy: 0.23%
#
# Test loss:0.00278 | Test accuracy: 0.20%
#
# Test loss:0.00226 | Test accuracy: 0.25%
#
# Test loss:0.00203 | Test accuracy: 0.22%
#
# Test loss:0.00261 | Test accuracy: 0.21%
#
# Test loss:0.00200 | Test accuracy: 0.26%
#
# Test loss:0.00258 | Test accuracy: 0.23%
#
# Test loss:0.00216 | Test accuracy: 0.23%
#
# Test loss:0.00235 | Test accuracy: 0.20%
#
# Test loss:0.00292 | Test accuracy: 0.21%
#
# Test loss:0.00201 | Test accuracy: 0.28%
#
# Test loss:0.00255 | Test accuracy: 0.23%
#
# Test loss:0.00242 | Test accuracy: 0.24%
#
# Test loss:0.00355 | Test accuracy: 0.20%
#
# Test loss:0.00223 | Test accuracy: 0.23%
#
# Test loss:0.00171 | Test accuracy: 0.26%
#
# Test loss:0.00227 | Test accuracy: 0.23%
#
# Test loss:0.00215 | Test accuracy: 0.22%
#
# Test loss:0.00256 | Test accuracy: 0.23%
#
# Test loss:0.00301 | Test accuracy: 0.20%
#
# Test loss:0.00233 | Test accuracy: 0.24%
#
# Test loss:0.00108 | Test accuracy: 0.29%
#
# Test loss:0.00195 | Test accuracy: 0.27%
#
# Test loss:0.00257 | Test accuracy: 0.22%
#
# Test loss:0.00187 | Test accuracy: 0.24%
#
# Test loss:0.00235 | Test accuracy: 0.23%
#
# Test loss:0.00221 | Test accuracy: 0.22%
#
# Test loss:0.00205 | Test accuracy: 0.23%
#
# Test loss:0.00259 | Test accuracy: 0.23%
#
# Test loss:0.00214 | Test accuracy: 0.23%
#
# Test loss:0.00205 | Test accuracy: 0.23%
#
# Test loss:0.00240 | Test accuracy: 0.23%
#
# Test loss:0.00204 | Test accuracy: 0.23%
#
# Test loss:0.00307 | Test accuracy: 0.21%
#
# Test loss:0.00313 | Test accuracy: 0.21%
#
# Test loss:0.00187 | Test accuracy: 0.27%
#
# Test loss:0.00252 | Test accuracy: 0.23%
#
# Test loss:0.00150 | Test accuracy: 0.26%
#
# Test loss:0.00223 | Test accuracy: 0.25%
#
# Test loss:0.00196 | Test accuracy: 0.26%
#
# Test loss:0.00310 | Test accuracy: 0.21%
#
# Test loss:0.00297 | Test accuracy: 0.22%
#
# Test loss:0.00299 | Test accuracy: 0.23%
#
# Test loss:0.00192 | Test accuracy: 0.25%
#
# Test loss:0.00187 | Test accuracy: 0.22%
#
# Test loss:0.00268 | Test accuracy: 0.22%
#
# Test loss:0.00148 | Test accuracy: 0.26%
#
# Test loss:0.00167 | Test accuracy: 0.25%
#
# Test loss:0.00364 | Test accuracy: 0.19%
#
# Test loss:0.00202 | Test accuracy: 0.23%
#
# Test loss:0.00352 | Test accuracy: 0.22%
#
# Test loss:0.00186 | Test accuracy: 0.27%
#
# Test loss:0.00241 | Test accuracy: 0.26%
#
# Test loss:0.00271 | Test accuracy: 0.22%
#
# Test loss:0.00223 | Test accuracy: 0.22%
#
# Test loss:0.00216 | Test accuracy: 0.26%
#
# Test loss:0.00281 | Test accuracy: 0.20%
#
# Test loss:0.00206 | Test accuracy: 0.23%
#
# Test loss:0.00296 | Test accuracy: 0.20%
#
# Test loss:0.00143 | Test accuracy: 0.26%
#
# Test loss:0.00346 | Test accuracy: 0.24%
#
# Test loss:0.00168 | Test accuracy: 0.26%
#
# Test loss:0.00215 | Test accuracy: 0.22%
#
# Test loss:0.00253 | Test accuracy: 0.22%
#
# Test loss:0.00147 | Test accuracy: 0.27%
#
# Test loss:0.00178 | Test accuracy: 0.25%
#
# Test loss:0.00170 | Test accuracy: 0.26%
#
# Test loss:0.00157 | Test accuracy: 0.25%
#
# Test loss:0.00203 | Test accuracy: 0.25%
#
# Test loss:0.00170 | Test accuracy: 0.25%
#
# Test loss:0.00187 | Test accuracy: 0.25%
#
# Test loss:0.00214 | Test accuracy: 0.27%
#
# Test loss:0.00252 | Test accuracy: 0.25%
#
# Test loss:0.00279 | Test accuracy: 0.22%
#
# Test loss:0.00177 | Test accuracy: 0.26%
#
# Test loss:0.00186 | Test accuracy: 0.23%
#
# Test loss:0.00322 | Test accuracy: 0.21%
#
# Test loss:0.00348 | Test accuracy: 0.19%
#
# Test loss:0.00273 | Test accuracy: 0.22%
#
# Test loss:0.00169 | Test accuracy: 0.25%
#
# Test loss:0.00205 | Test accuracy: 0.24%
#
# Test loss:0.00222 | Test accuracy: 0.22%
#
# Test loss:0.00238 | Test accuracy: 0.24%
#
# Test loss:0.00317 | Test accuracy: 0.20%
#
# Test loss:0.00161 | Test accuracy: 0.27%
#
# Test loss:0.00155 | Test accuracy: 0.27%
#
# Test loss:0.00157 | Test accuracy: 0.24%
#
# Test loss:0.00177 | Test accuracy: 0.25%
#
# Test loss:0.00214 | Test accuracy: 0.25%
#
# Test loss:0.00239 | Test accuracy: 0.23%
#
# Test loss:0.00316 | Test accuracy: 0.20%
#
# Test loss:0.00257 | Test accuracy: 0.25%
#
# Test loss:0.00238 | Test accuracy: 0.22%
#
# Test loss:0.00340 | Test accuracy: 0.18%
#
# Test loss:0.00272 | Test accuracy: 0.21%
#
# Test loss:0.00199 | Test accuracy: 0.25%
#
# Test loss:0.00282 | Test accuracy: 0.23%
#
# Test loss:0.00238 | Test accuracy: 0.21%
#
# Test loss:0.00087 | Test accuracy: 0.29%
#
# Test loss:0.00242 | Test accuracy: 0.22%
#
# Test loss:0.00260 | Test accuracy: 0.25%
#
# Test loss:0.00247 | Test accuracy: 0.24%
#
# Test loss:0.00225 | Test accuracy: 0.24%
#
# Test loss:0.00207 | Test accuracy: 0.25%
#
# Test loss:0.00186 | Test accuracy: 0.26%
#
# Test loss:0.00217 | Test accuracy: 0.24%
#
# Test loss:0.00225 | Test accuracy: 0.23%
#
# Test loss:0.00131 | Test accuracy: 0.28%
#
# Test loss:0.00138 | Test accuracy: 0.26%
#
# Test loss:0.00149 | Test accuracy: 0.29%
#
# Test loss:0.00270 | Test accuracy: 0.23%
#
# Test loss:0.00126 | Test accuracy: 0.26%
#
# Test loss:0.00286 | Test accuracy: 0.21%
#
# Test loss:0.00233 | Test accuracy: 0.24%
#
# Test loss:0.00329 | Test accuracy: 0.21%
#
# Test loss:0.00217 | Test accuracy: 0.22%
#
# Test loss:0.00128 | Test accuracy: 0.28%
#
# Epoch: 2
# ----------
# Train loss: 0.67027 | Train accuracy: 75.94%
# Test loss:0.00182 | Test accuracy: 0.25%
#
# Test loss:0.00212 | Test accuracy: 0.22%
#
# Test loss:0.00232 | Test accuracy: 0.24%
#
# Test loss:0.00125 | Test accuracy: 0.27%
#
# Test loss:0.00122 | Test accuracy: 0.30%
#
# Test loss:0.00121 | Test accuracy: 0.27%
#
# Test loss:0.00155 | Test accuracy: 0.27%
#
# Test loss:0.00219 | Test accuracy: 0.26%
#
# Test loss:0.00241 | Test accuracy: 0.22%
#
# Test loss:0.00210 | Test accuracy: 0.27%
#
# Test loss:0.00233 | Test accuracy: 0.21%
#
# Test loss:0.00268 | Test accuracy: 0.22%
#
# Test loss:0.00145 | Test accuracy: 0.26%
#
# Test loss:0.00174 | Test accuracy: 0.27%
#
# Test loss:0.00291 | Test accuracy: 0.24%
#
# Test loss:0.00173 | Test accuracy: 0.26%
#
# Test loss:0.00181 | Test accuracy: 0.24%
#
# Test loss:0.00238 | Test accuracy: 0.22%
#
# Test loss:0.00212 | Test accuracy: 0.24%
#
# Test loss:0.00261 | Test accuracy: 0.21%
#
# Test loss:0.00179 | Test accuracy: 0.26%
#
# Test loss:0.00231 | Test accuracy: 0.25%
#
# Test loss:0.00230 | Test accuracy: 0.27%
#
# Test loss:0.00242 | Test accuracy: 0.24%
#
# Test loss:0.00080 | Test accuracy: 0.30%
#
# Test loss:0.00220 | Test accuracy: 0.24%
#
# Test loss:0.00168 | Test accuracy: 0.25%
#
# Test loss:0.00180 | Test accuracy: 0.28%
#
# Test loss:0.00216 | Test accuracy: 0.22%
#
# Test loss:0.00128 | Test accuracy: 0.27%
#
# Test loss:0.00356 | Test accuracy: 0.20%
#
# Test loss:0.00234 | Test accuracy: 0.23%
#
# Test loss:0.00186 | Test accuracy: 0.23%
#
# Test loss:0.00159 | Test accuracy: 0.26%
#
# Test loss:0.00258 | Test accuracy: 0.22%
#
# Test loss:0.00168 | Test accuracy: 0.25%
#
# Test loss:0.00211 | Test accuracy: 0.25%
#
# Test loss:0.00152 | Test accuracy: 0.25%
#
# Test loss:0.00232 | Test accuracy: 0.23%
#
# Test loss:0.00167 | Test accuracy: 0.26%
#
# Test loss:0.00261 | Test accuracy: 0.25%
#
# Test loss:0.00263 | Test accuracy: 0.25%
#
# Test loss:0.00191 | Test accuracy: 0.25%
#
# Test loss:0.00237 | Test accuracy: 0.22%
#
# Test loss:0.00080 | Test accuracy: 0.28%
#
# Test loss:0.00257 | Test accuracy: 0.24%
#
# Test loss:0.00299 | Test accuracy: 0.20%
#
# Test loss:0.00244 | Test accuracy: 0.24%
#
# Test loss:0.00158 | Test accuracy: 0.23%
#
# Test loss:0.00181 | Test accuracy: 0.25%
#
# Test loss:0.00279 | Test accuracy: 0.19%
#
# Test loss:0.00237 | Test accuracy: 0.22%
#
# Test loss:0.00155 | Test accuracy: 0.28%
#
# Test loss:0.00192 | Test accuracy: 0.25%
#
# Test loss:0.00211 | Test accuracy: 0.27%
#
# Test loss:0.00150 | Test accuracy: 0.28%
#
# Test loss:0.00226 | Test accuracy: 0.23%
#
# Test loss:0.00290 | Test accuracy: 0.21%
#
# Test loss:0.00096 | Test accuracy: 0.29%
#
# Test loss:0.00091 | Test accuracy: 0.30%
#
# Test loss:0.00179 | Test accuracy: 0.25%
#
# Test loss:0.00338 | Test accuracy: 0.18%
#
# Test loss:0.00269 | Test accuracy: 0.23%
#
# Test loss:0.00307 | Test accuracy: 0.22%
#
# Test loss:0.00295 | Test accuracy: 0.21%
#
# Test loss:0.00174 | Test accuracy: 0.25%
#
# Test loss:0.00163 | Test accuracy: 0.26%
#
# Test loss:0.00225 | Test accuracy: 0.26%
#
# Test loss:0.00268 | Test accuracy: 0.21%
#
# Test loss:0.00131 | Test accuracy: 0.28%
#
# Test loss:0.00150 | Test accuracy: 0.27%
#
# Test loss:0.00166 | Test accuracy: 0.25%
#
# Test loss:0.00257 | Test accuracy: 0.22%
#
# Test loss:0.00230 | Test accuracy: 0.24%
#
# Test loss:0.00222 | Test accuracy: 0.24%
#
# Test loss:0.00209 | Test accuracy: 0.24%
#
# Test loss:0.00148 | Test accuracy: 0.27%
#
# Test loss:0.00243 | Test accuracy: 0.23%
#
# Test loss:0.00294 | Test accuracy: 0.22%
#
# Test loss:0.00184 | Test accuracy: 0.25%
#
# Test loss:0.00118 | Test accuracy: 0.28%
#
# Test loss:0.00204 | Test accuracy: 0.25%
#
# Test loss:0.00216 | Test accuracy: 0.25%
#
# Test loss:0.00223 | Test accuracy: 0.26%
#
# Test loss:0.00226 | Test accuracy: 0.23%
#
# Test loss:0.00247 | Test accuracy: 0.26%
#
# Test loss:0.00185 | Test accuracy: 0.24%
#
# Test loss:0.00204 | Test accuracy: 0.26%
#
# Test loss:0.00293 | Test accuracy: 0.21%
#
# Test loss:0.00273 | Test accuracy: 0.23%
#
# Test loss:0.00376 | Test accuracy: 0.18%
#
# Test loss:0.00283 | Test accuracy: 0.22%
#
# Test loss:0.00147 | Test accuracy: 0.27%
#
# Test loss:0.00279 | Test accuracy: 0.22%
#
# Test loss:0.00231 | Test accuracy: 0.23%
#
# Test loss:0.00251 | Test accuracy: 0.22%
#
# Test loss:0.00221 | Test accuracy: 0.21%
#
# Test loss:0.00237 | Test accuracy: 0.25%
#
# Test loss:0.00174 | Test accuracy: 0.26%
#
# Test loss:0.00223 | Test accuracy: 0.24%
#
# Test loss:0.00204 | Test accuracy: 0.25%
#
# Test loss:0.00353 | Test accuracy: 0.20%
#
# Test loss:0.00227 | Test accuracy: 0.24%
#
# Test loss:0.00262 | Test accuracy: 0.23%
#
# Test loss:0.00208 | Test accuracy: 0.23%
#
# Test loss:0.00109 | Test accuracy: 0.28%
#
# Test loss:0.00234 | Test accuracy: 0.23%
#
# Test loss:0.00216 | Test accuracy: 0.22%
#
# Test loss:0.00385 | Test accuracy: 0.20%
#
# Test loss:0.00179 | Test accuracy: 0.25%
#
# Test loss:0.00253 | Test accuracy: 0.23%
#
# Test loss:0.00204 | Test accuracy: 0.26%
#
# Test loss:0.00262 | Test accuracy: 0.23%
#
# Test loss:0.00122 | Test accuracy: 0.29%
#
# Test loss:0.00205 | Test accuracy: 0.24%
#
# Test loss:0.00223 | Test accuracy: 0.24%
#
# Test loss:0.00207 | Test accuracy: 0.25%
#
# Test loss:0.00210 | Test accuracy: 0.23%
#
# Test loss:0.00230 | Test accuracy: 0.24%
#
# Test loss:0.00228 | Test accuracy: 0.26%
#
# Test loss:0.00215 | Test accuracy: 0.24%
#
# Test loss:0.00172 | Test accuracy: 0.24%
#
# Test loss:0.00300 | Test accuracy: 0.20%
#
# Test loss:0.00305 | Test accuracy: 0.21%
#
# Test loss:0.00216 | Test accuracy: 0.25%
#
# Test loss:0.00183 | Test accuracy: 0.26%
#
# Test loss:0.00297 | Test accuracy: 0.22%
#
# Test loss:0.00309 | Test accuracy: 0.20%
#
# Test loss:0.00172 | Test accuracy: 0.24%
#
# Test loss:0.00416 | Test accuracy: 0.18%
#
# Test loss:0.00214 | Test accuracy: 0.23%
#
# Test loss:0.00264 | Test accuracy: 0.22%
#
# Test loss:0.00236 | Test accuracy: 0.22%
#
# Test loss:0.00177 | Test accuracy: 0.27%
#
# Test loss:0.00232 | Test accuracy: 0.24%
#
# Test loss:0.00122 | Test accuracy: 0.28%
#
# Test loss:0.00171 | Test accuracy: 0.26%
#
# Test loss:0.00210 | Test accuracy: 0.24%
#
# Test loss:0.00168 | Test accuracy: 0.25%
#
# Test loss:0.00141 | Test accuracy: 0.28%
#
# Test loss:0.00219 | Test accuracy: 0.25%
#
# Test loss:0.00063 | Test accuracy: 0.30%
#
# Test loss:0.00156 | Test accuracy: 0.26%
#
# Test loss:0.00176 | Test accuracy: 0.26%
#
# Test loss:0.00197 | Test accuracy: 0.24%
#
# Test loss:0.00247 | Test accuracy: 0.24%
#
# Test loss:0.00379 | Test accuracy: 0.19%
#
# Test loss:0.00189 | Test accuracy: 0.26%
#
# Test loss:0.00294 | Test accuracy: 0.19%
#
# Test loss:0.00170 | Test accuracy: 0.27%
#
# Test loss:0.00341 | Test accuracy: 0.22%
#
# Test loss:0.00240 | Test accuracy: 0.23%
#
# Test loss:0.00187 | Test accuracy: 0.24%
#
# Test loss:0.00222 | Test accuracy: 0.23%
#
# Test loss:0.00315 | Test accuracy: 0.21%
#
# Test loss:0.00217 | Test accuracy: 0.24%
#
# Test loss:0.00297 | Test accuracy: 0.21%
#
# Test loss:0.00264 | Test accuracy: 0.22%
#
# Test loss:0.00381 | Test accuracy: 0.20%
#
# Test loss:0.00178 | Test accuracy: 0.26%
#
# Test loss:0.00204 | Test accuracy: 0.26%
#
# Test loss:0.00278 | Test accuracy: 0.24%
#
# Test loss:0.00329 | Test accuracy: 0.21%
#
# Test loss:0.00178 | Test accuracy: 0.27%
#
# Test loss:0.00312 | Test accuracy: 0.21%
#
# Test loss:0.00209 | Test accuracy: 0.25%
#
# Test loss:0.00223 | Test accuracy: 0.27%
#
# Test loss:0.00120 | Test accuracy: 0.27%
#
# Test loss:0.00126 | Test accuracy: 0.27%
#
# Test loss:0.00194 | Test accuracy: 0.23%
#
# Test loss:0.00248 | Test accuracy: 0.24%
#
# Test loss:0.00202 | Test accuracy: 0.26%
#
# Test loss:0.00418 | Test accuracy: 0.19%
#
# Test loss:0.00207 | Test accuracy: 0.25%
#
# Test loss:0.00416 | Test accuracy: 0.18%
#
# Test loss:0.00241 | Test accuracy: 0.24%
#
# Test loss:0.00286 | Test accuracy: 0.17%
#
# Test loss:0.00349 | Test accuracy: 0.17%
#
# Test loss:0.00247 | Test accuracy: 0.24%
#
# Test loss:0.00216 | Test accuracy: 0.25%
#
# Test loss:0.00227 | Test accuracy: 0.25%
#
# Test loss:0.00274 | Test accuracy: 0.25%
#
# Test loss:0.00226 | Test accuracy: 0.26%
#
# Test loss:0.00083 | Test accuracy: 0.30%
#
# Test loss:0.00161 | Test accuracy: 0.26%
#
# Test loss:0.00211 | Test accuracy: 0.22%
#
# Test loss:0.00263 | Test accuracy: 0.21%
#
# Test loss:0.00210 | Test accuracy: 0.23%
#
# Test loss:0.00220 | Test accuracy: 0.24%
#
# Test loss:0.00142 | Test accuracy: 0.26%
#
# Test loss:0.00237 | Test accuracy: 0.21%
#
# Test loss:0.00209 | Test accuracy: 0.24%
#
# Test loss:0.00256 | Test accuracy: 0.21%
#
# Test loss:0.00221 | Test accuracy: 0.24%
#
# Test loss:0.00182 | Test accuracy: 0.25%
#
# Test loss:0.00237 | Test accuracy: 0.23%
#
# Test loss:0.00272 | Test accuracy: 0.20%
#
# Test loss:0.00276 | Test accuracy: 0.21%
#
# Test loss:0.00232 | Test accuracy: 0.22%
#
# Test loss:0.00189 | Test accuracy: 0.26%
#
# Test loss:0.00249 | Test accuracy: 0.22%
#
# Test loss:0.00189 | Test accuracy: 0.27%
#
# Test loss:0.00223 | Test accuracy: 0.24%
#
# Test loss:0.00201 | Test accuracy: 0.22%
#
# Test loss:0.00226 | Test accuracy: 0.24%
#
# Test loss:0.00300 | Test accuracy: 0.20%
#
# Test loss:0.00205 | Test accuracy: 0.28%
#
# Test loss:0.00278 | Test accuracy: 0.22%
#
# Test loss:0.00256 | Test accuracy: 0.22%
#
# Test loss:0.00319 | Test accuracy: 0.21%
#
# Test loss:0.00194 | Test accuracy: 0.23%
#
# Test loss:0.00124 | Test accuracy: 0.27%
#
# Test loss:0.00201 | Test accuracy: 0.24%
#
# Test loss:0.00191 | Test accuracy: 0.24%
#
# Test loss:0.00237 | Test accuracy: 0.23%
#
# Test loss:0.00291 | Test accuracy: 0.22%
#
# Test loss:0.00207 | Test accuracy: 0.23%
#
# Test loss:0.00113 | Test accuracy: 0.26%
#
# Test loss:0.00175 | Test accuracy: 0.27%
#
# Test loss:0.00255 | Test accuracy: 0.22%
#
# Test loss:0.00188 | Test accuracy: 0.23%
#
# Test loss:0.00203 | Test accuracy: 0.25%
#
# Test loss:0.00229 | Test accuracy: 0.23%
#
# Test loss:0.00153 | Test accuracy: 0.26%
#
# Test loss:0.00305 | Test accuracy: 0.21%
#
# Test loss:0.00240 | Test accuracy: 0.21%
#
# Test loss:0.00177 | Test accuracy: 0.26%
#
# Test loss:0.00179 | Test accuracy: 0.26%
#
# Test loss:0.00207 | Test accuracy: 0.22%
#
# Test loss:0.00302 | Test accuracy: 0.19%
#
# Test loss:0.00307 | Test accuracy: 0.21%
#
# Test loss:0.00172 | Test accuracy: 0.26%
#
# Test loss:0.00242 | Test accuracy: 0.23%
#
# Test loss:0.00094 | Test accuracy: 0.28%
#
# Test loss:0.00250 | Test accuracy: 0.20%
#
# Test loss:0.00155 | Test accuracy: 0.28%
#
# Test loss:0.00300 | Test accuracy: 0.20%
#
# Test loss:0.00245 | Test accuracy: 0.24%
#
# Test loss:0.00273 | Test accuracy: 0.23%
#
# Test loss:0.00223 | Test accuracy: 0.22%
#
# Test loss:0.00169 | Test accuracy: 0.24%
#
# Test loss:0.00244 | Test accuracy: 0.22%
#
# Test loss:0.00160 | Test accuracy: 0.26%
#
# Test loss:0.00164 | Test accuracy: 0.27%
#
# Test loss:0.00322 | Test accuracy: 0.20%
#
# Test loss:0.00195 | Test accuracy: 0.24%
#
# Test loss:0.00334 | Test accuracy: 0.22%
#
# Test loss:0.00169 | Test accuracy: 0.27%
#
# Test loss:0.00241 | Test accuracy: 0.24%
#
# Test loss:0.00263 | Test accuracy: 0.21%
#
# Test loss:0.00262 | Test accuracy: 0.22%
#
# Test loss:0.00208 | Test accuracy: 0.24%
#
# Test loss:0.00249 | Test accuracy: 0.22%
#
# Test loss:0.00191 | Test accuracy: 0.24%
#
# Test loss:0.00285 | Test accuracy: 0.21%
#
# Test loss:0.00138 | Test accuracy: 0.27%
#
# Test loss:0.00336 | Test accuracy: 0.22%
#
# Test loss:0.00172 | Test accuracy: 0.28%
#
# Test loss:0.00229 | Test accuracy: 0.21%
#
# Test loss:0.00234 | Test accuracy: 0.22%
#
# Test loss:0.00118 | Test accuracy: 0.28%
#
# Test loss:0.00175 | Test accuracy: 0.26%
#
# Test loss:0.00153 | Test accuracy: 0.27%
#
# Test loss:0.00146 | Test accuracy: 0.26%
#
# Test loss:0.00192 | Test accuracy: 0.25%
#
# Test loss:0.00168 | Test accuracy: 0.25%
#
# Test loss:0.00181 | Test accuracy: 0.23%
#
# Test loss:0.00204 | Test accuracy: 0.28%
#
# Test loss:0.00258 | Test accuracy: 0.24%
#
# Test loss:0.00266 | Test accuracy: 0.22%
#
# Test loss:0.00165 | Test accuracy: 0.27%
#
# Test loss:0.00140 | Test accuracy: 0.27%
#
# Test loss:0.00301 | Test accuracy: 0.21%
#
# Test loss:0.00378 | Test accuracy: 0.20%
#
# Test loss:0.00282 | Test accuracy: 0.23%
#
# Test loss:0.00142 | Test accuracy: 0.26%
#
# Test loss:0.00162 | Test accuracy: 0.25%
#
# Test loss:0.00249 | Test accuracy: 0.23%
#
# Test loss:0.00243 | Test accuracy: 0.25%
#
# Test loss:0.00254 | Test accuracy: 0.20%
#
# Test loss:0.00134 | Test accuracy: 0.27%
#
# Test loss:0.00132 | Test accuracy: 0.29%
#
# Test loss:0.00141 | Test accuracy: 0.25%
#
# Test loss:0.00149 | Test accuracy: 0.27%
#
# Test loss:0.00215 | Test accuracy: 0.23%
#
# Test loss:0.00281 | Test accuracy: 0.22%
#
# Test loss:0.00327 | Test accuracy: 0.21%
#
# Test loss:0.00236 | Test accuracy: 0.23%
#
# Test loss:0.00252 | Test accuracy: 0.22%
#
# Test loss:0.00328 | Test accuracy: 0.21%
#
# Test loss:0.00258 | Test accuracy: 0.23%
#
# Test loss:0.00187 | Test accuracy: 0.25%
#
# Test loss:0.00238 | Test accuracy: 0.23%
#
# Test loss:0.00205 | Test accuracy: 0.25%
#
# Test loss:0.00090 | Test accuracy: 0.29%
#
# Test loss:0.00242 | Test accuracy: 0.23%
#
# Test loss:0.00258 | Test accuracy: 0.26%
#
# Test loss:0.00214 | Test accuracy: 0.23%
#
# Test loss:0.00238 | Test accuracy: 0.24%
#
# Test loss:0.00197 | Test accuracy: 0.25%
#
# Test loss:0.00145 | Test accuracy: 0.26%
#
# Test loss:0.00249 | Test accuracy: 0.23%
#
# Test loss:0.00232 | Test accuracy: 0.24%
#
# Test loss:0.00118 | Test accuracy: 0.28%
#
# Test loss:0.00107 | Test accuracy: 0.27%
#
# Test loss:0.00150 | Test accuracy: 0.25%
#
# Test loss:0.00247 | Test accuracy: 0.23%
#
# Test loss:0.00114 | Test accuracy: 0.27%
#
# Test loss:0.00286 | Test accuracy: 0.21%
#
# Test loss:0.00207 | Test accuracy: 0.25%
#
# Test loss:0.00312 | Test accuracy: 0.21%
#
# Test loss:0.00228 | Test accuracy: 0.24%
#
# Test loss:0.00128 | Test accuracy: 0.28%
#
# Train time on cuda: 3709.206 seconds

# %%
torch.manual_seed(42)

# Note: This will error due to 'eval_model()' not using device agnostic code
model_1_results = eval_model(model=model_1,
                             data_loader=test_dataloader,
                             loss_fn=loss_fn,
                             accuracy_fn=accuracy_fn)
model_1_results
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[42], line 4
#       1 torch.manual_seed(42)
#       3 # Note: This will error due to 'eval_model()' not using device agnostic code
# ----> 4 model_1_results = eval_model(model=model_1,
#       5                              data_loader=test_dataloader,
#       6                              loss_fn=loss_fn,
#       7                              accuracy_fn=accuracy_fn)
#       8 model_1_results
#
# Cell In[27], line 24, in eval_model(model, data_loader, loss_fn, accuracy_fn)
#      21 with torch.inference_mode():
#      22     for X, y in data_loader:
#      23         # Make predictions with the model
# ---> 24         y_pred = model(X)
#      26         # Accumulate the loss and accuracy values per batch
#      27         loss += loss_fn(y_pred, y)
#
# File c:\Users\CSR\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[33], line 14, in FashionMNISTModelV1.forward(self, x)
#      13 def forward(self, x: torch.tensor):
# ---> 14     return self.layer_stack(x)
#
# File c:\Users\CSR\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\CSR\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\CSR\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\CSR\anaconda3\envs\ml\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu! (when checking argument for argument mat1 in method wrapper_CUDA_addmm)

# %%
# Move values to device
torch.manual_seed(42)
def eval_model(model: torch.nn.Module, 
               data_loader: torch.utils.data.DataLoader, 
               loss_fn: torch.nn.Module, 
               accuracy_fn, 
               device: torch.device = device):
    """Evaluates a given model on a given dataset.

    Args:
        model (torch.nn.Module): A PyTorch model capable of making predictions on data_loader.
        data_loader (torch.utils.data.DataLoader): The target dataset to predict on.
        loss_fn (torch.nn.Module): The loss function of model.
        accuracy_fn: An accuracy function to compare the models predictions to the truth labels.
        device (str, optional): Target device to compute on. Defaults to device.

    Returns:
        (dict): Results of model making predictions on data_loader.
    """
    loss, acc = 0, 0
    model.eval()
    with torch.inference_mode():
        for X, y in data_loader:
            # Send data to the target device
            X, y = X.to(device), y.to(device)
            y_pred = model(X)
            loss += loss_fn(y_pred, y)
            acc += accuracy_fn(y_true=y, y_pred=y_pred.argmax(dim=1))
        
        # Scale loss and acc
        loss /= len(data_loader)
        acc /= len(data_loader)
    return {"model_name": model.__class__.__name__, # only works when model was created with a class
            "model_loss": loss.item(),
            "model_acc": acc}

# Calculate model 1 results with device-agnostic code 
model_1_results = eval_model(model=model_1, data_loader=test_dataloader,
    loss_fn=loss_fn, accuracy_fn=accuracy_fn,
    device=device
)
model_1_results
# Out:
# {'model_name': 'FashionMNISTModelV1',
#  'model_loss': 0.6850008368492126,
#  'model_acc': 75.01996805111821}

# %%
# Check baseline results
model_0_result
# Out:
# {'model_name': 'FashionMNISTModelV0',
#  'model_loss': 0.4766390025615692,
#  'model_acc': 83.42651757188499}

# %% [markdown]
# ## Model 2: Building a Convolutional Neural Network (CNN)

# %%
# Create a convolutional neural network
class FashionMNISTModelV2(nn.Module):
    """
    Model architecture copying TinyVGG from:
    https://poloclub.github.io/cnn-explainer/
    """
    def __init__(self, input_shape: int, hidden_units: int, outputshape: int):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3, # how big is the square that's going over the image?
                      stride=1, # default
                      padding=1), # options = 'valid' (no padding) or "same" (output has same shape as input) or int for specific number
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2) # default stride value is same as kernel_size
        )
        self.blcok_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Where did this in_features shape come from?
            # It's because each layer of our network compresses and changes the shape of our inputs data.
            nn.Linear(in_features=hidden_units*7*7,
                      out_features=outputshape)
        )

    def forward(self, x: torch.Tensor):
        x = self.block_1(x)
        print(x.shape)
        x = self.blcok_2(x)
        print(x.shape)
        x = self.classifier(x)
        print(x.shape)
        return x
    
torch.manual_seed(42)
model_2 = FashionMNISTModelV2(input_shape=1,
                              hidden_units=10,
                              outputshape=len(class_names)).to(device)
model_2
# Out:
# FashionMNISTModelV2(
#   (block_1): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (blcok_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=490, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Stepping through nn.Conv2d()

# %%
torch.manual_seed(42)

# Create sample batch of random numbers with same size as image batch
images = torch.randn(size=(32, 3, 64, 64)) # [bartch_size, color_channels, height, width]
test_image = images[0] # get a single image for testing
print(f"Image batch shape: {images.shape} -> [bartch_size, color_channels, height, width]")
print(f"Single image shape: {test_image.shape} -> [color_channels, height, width]")
print(f"Single image pixel values:\n{test_image}")
# Out:
# Image batch shape: torch.Size([32, 3, 64, 64]) -> [bartch_size, color_channels, height, width]
# Single image shape: torch.Size([3, 64, 64]) -> [color_channels, height, width]
# Single image pixel values:
# tensor([[[ 1.9269,  1.4873,  0.9007,  ...,  1.8446, -1.1845,  1.3835],
#          [ 1.4451,  0.8564,  2.2181,  ...,  0.3399,  0.7200,  0.4114],
#          [ 1.9312,  1.0119, -1.4364,  ..., -0.5558,  0.7043,  0.7099],
#          ...,
#          [-0.5610, -0.4830,  0.4770,  ..., -0.2713, -0.9537, -0.6737],
#          [ 0.3076, -0.1277,  0.0366,  ..., -2.0060,  0.2824, -0.8111],
#          [-1.5486,  0.0485, -0.7712,  ..., -0.1403,  0.9416, -0.0118]],
#
#         [[-0.5197,  1.8524,  1.8365,  ...,  0.8935, -1.5114, -0.8515],
#          [ 2.0818,  1.0677, -1.4277,  ...,  1.6612, -2.6223, -0.4319],
#          [-0.1010, -0.4388, -1.9775,  ...,  0.2106,  0.2536, -0.7318],
#          ...,
#          [ 0.2779,  0.7342, -0.3736,  ..., -0.4601,  0.1815,  0.1850],
#          [ 0.7205, -0.2833,  0.0937,  ..., -0.1002, -2.3609,  2.2465],
#          [-1.3242, -0.1973,  0.2920,  ...,  0.5409,  0.6940,  1.8563]],
#
#         [[-0.7978,  1.0261,  1.1465,  ...,  1.2134,  0.9354, -0.0780],
#          [-1.4647, -1.9571,  0.1017,  ..., -1.9986, -0.7409,  0.7011],
#          [-1.3938,  0.8466, -1.7191,  ..., -1.1867,  0.1320,  0.3407],
#          ...,
#          [ 0.8206, -0.3745,  1.2499,  ..., -0.0676,  0.0385,  0.6335],
#          [-0.5589, -0.3393,  0.2347,  ...,  2.1181,  2.4569,  1.3083],
#          [-0.4092,  1.5199,  0.2401,  ..., -0.2558,  0.7870,  0.9924]]])

# %%
torch.manual_seed(42)

# Create a convolutional layer with same dimensions as TinyVGG
# (try chaning any of the parameters and see what happens)
conv_layer = nn.Conv2d(in_channels=3,
                       out_channels=10,
                       kernel_size=3,
                       stride=1,
                       padding=0) # also try using "valid" or "same" here

# Pass the data through the convolutional layer
conv_layer(test_image)
# Out:
# tensor([[[ 1.5396,  0.0516,  0.6454,  ..., -0.3673,  0.8711,  0.4256],
#          [ 0.3662,  1.0114, -0.5997,  ...,  0.8983,  0.2809, -0.2741],
#          [ 1.2664, -1.4054,  0.3727,  ..., -0.3409,  1.2191, -0.0463],
#          ...,
#          [-0.1541,  0.5132, -0.3624,  ..., -0.2360, -0.4609, -0.0035],
#          [ 0.2981, -0.2432,  1.5012,  ..., -0.6289, -0.7283, -0.5767],
#          [-0.0386, -0.0781, -0.0388,  ...,  0.2842,  0.4228, -0.1802]],
#
#         [[-0.2840, -0.0319, -0.4455,  ..., -0.7956,  1.5599, -1.2449],
#          [ 0.2753, -0.1262, -0.6541,  ..., -0.2211,  0.1999, -0.8856],
#          [-0.5404, -1.5489,  0.0249,  ..., -0.5932, -1.0913, -0.3849],
#          ...,
#          [ 0.3870, -0.4064, -0.8236,  ...,  0.1734, -0.4330, -0.4951],
#          [-0.1984, -0.6386,  1.0263,  ..., -0.9401, -0.0585, -0.7833],
#          [-0.6306, -0.2052, -0.3694,  ..., -1.3248,  0.2456, -0.7134]],
#
#         [[ 0.4414,  0.5100,  0.4846,  ..., -0.8484,  0.2638,  1.1258],
#          [ 0.8117,  0.3191, -0.0157,  ...,  1.2686,  0.2319,  0.5003],
#          [ 0.3212,  0.0485, -0.2581,  ...,  0.2258,  0.2587, -0.8804],
#          ...,
#          [-0.1144, -0.1869,  0.0160,  ..., -0.8346,  0.0974,  0.8421],
#          [ 0.2941,  0.4417,  0.5866,  ..., -0.1224,  0.4814, -0.4799],
#          [ 0.6059, -0.0415, -0.2028,  ...,  0.1170,  0.2521, -0.4372]],
#
#         ...,
#
#         [[-0.2560, -0.0477,  0.6380,  ...,  0.6436,  0.7553, -0.7055],
#          [ 1.5595, -0.2209, -0.9486,  ..., -0.4876,  0.7754,  0.0750],
#          [-0.0797,  0.2471,  1.1300,  ...,  0.1505,  0.2354,  0.9576],
#          ...,
#          [ 1.1065,  0.6839,  1.2183,  ...,  0.3015, -0.1910, -0.1902],
#          [-0.3486, -0.7173, -0.3582,  ...,  0.4917,  0.7219,  0.1513],
#          [ 0.0119,  0.1017,  0.7839,  ..., -0.3752, -0.8127, -0.1257]],
#
#         [[ 0.3841,  1.1322,  0.1620,  ...,  0.7010,  0.0109,  0.6058],
#          [ 0.1664,  0.1873,  1.5924,  ...,  0.3733,  0.9096, -0.5399],
#          [ 0.4094, -0.0861, -0.7935,  ..., -0.1285, -0.9932, -0.3013],
#          ...,
#          [ 0.2688, -0.5630, -1.1902,  ...,  0.4493,  0.5404, -0.0103],
#          [ 0.0535,  0.4411,  0.5313,  ...,  0.0148, -1.0056,  0.3759],
#          [ 0.3031, -0.1590, -0.1316,  ..., -0.5384, -0.4271, -0.4876]],
#
#         [[-1.1865, -0.7280, -1.2331,  ..., -0.9013, -0.0542, -1.5949],
#          [-0.6345, -0.5920,  0.5326,  ..., -1.0395, -0.7963, -0.0647],
#          [-0.1132,  0.5166,  0.2569,  ...,  0.5595, -1.6881,  0.9485],
#          ...,
#          [-0.0254, -0.2669,  0.1927,  ..., -0.2917,  0.1088, -0.4807],
#          [-0.2609, -0.2328,  0.1404,  ..., -0.1325, -0.8436, -0.7524],
#          [-1.1399, -0.1751, -0.8705,  ...,  0.1589,  0.3377,  0.3493]]],
#        grad_fn=<SqueezeBackward1>)

# %%
# Print out the conv_layer internal parameters
print(conv_layer.state_dict())
# Out:
# OrderedDict([('weight', tensor([[[[ 0.1471,  0.1597, -0.0451],
#           [ 0.1768, -0.0422,  0.0388],
#           [-0.0937,  0.1130,  0.1697]],
#
#          [[-0.1412,  0.1673,  0.0360],
#           [ 0.1422,  0.0261,  0.0928],
#           [-0.0272,  0.1484,  0.0284]],
#
#          [[-0.0898,  0.0491, -0.0887],
#           [-0.0226, -0.0782,  0.1277],
#           [-0.1519, -0.0887, -0.0543]]],
#
#
#         [[[-0.1157,  0.0182, -0.1901],
#           [ 0.1738, -0.1635,  0.1486],
#           [ 0.0320, -0.0625,  0.1189]],
#
#          [[ 0.0300,  0.1555,  0.0210],
#           [-0.0607,  0.0517, -0.0522],
#           [ 0.0810,  0.1718,  0.1112]],
#
#          [[-0.0841,  0.1111,  0.0344],
#           [ 0.0977, -0.1173, -0.1905],
#           [-0.0744, -0.1476,  0.1579]]],
#
#
#         [[[ 0.0554,  0.0797,  0.0609],
#           [-0.0033,  0.1506, -0.1367],
#           [ 0.0121, -0.1314,  0.0593]],
#
#          [[-0.0663,  0.0590, -0.0401],
#           [ 0.1596, -0.1141, -0.1148],
#           [-0.1148,  0.1731,  0.0641]],
#
#          [[ 0.1852, -0.1588, -0.1909],
#           [-0.1506, -0.1295,  0.0780],
#           [ 0.0689,  0.1599, -0.0994]]],
#
#
#         [[[-0.1312,  0.1021, -0.0778],
#           [ 0.1168, -0.0457,  0.1101],
#           [-0.1495, -0.0971,  0.0587]],
#
#          [[ 0.0407, -0.0491,  0.1147],
#           [ 0.1308, -0.1396, -0.1027],
#           [ 0.1762, -0.0649, -0.0682]],
#
#          [[-0.1862, -0.1102,  0.0481],
#           [-0.0254, -0.1397,  0.0045],
#           [-0.1315, -0.1633, -0.1060]]],
#
#
#         [[[-0.1684, -0.1225,  0.1924],
#           [ 0.0363,  0.0593, -0.1795],
#           [-0.1264, -0.0641,  0.0301]],
#
#          [[-0.1693, -0.0829, -0.1152],
#           [ 0.0005, -0.0716, -0.0133],
#           [-0.1304, -0.1321, -0.1123]],
#
#          [[-0.0659, -0.1519,  0.1614],
#           [-0.0382,  0.1656,  0.0600],
#           [-0.1630,  0.1332, -0.0530]]],
#
#
#         [[[-0.0738, -0.1597, -0.1913],
#           [ 0.0551, -0.0420,  0.0749],
#           [-0.1579,  0.1429, -0.1413]],
#
#          [[-0.0332,  0.0402,  0.0994],
#           [ 0.1554,  0.1753, -0.1526],
#           [ 0.0484, -0.0828, -0.0211]],
#
#          [[-0.1440,  0.1753, -0.1412],
#           [ 0.1029,  0.0676,  0.0625],
#           [-0.1040,  0.1749,  0.0423]]],
#
#
#         [[[ 0.0248, -0.1696,  0.0808],
#           [-0.0289, -0.0882,  0.1653],
#           [ 0.0429, -0.1065, -0.0974]],
#
#          [[-0.0092,  0.1075, -0.0492],
#           [-0.1098, -0.0659, -0.1438],
#           [ 0.0686,  0.1490, -0.1812]],
#
#          [[ 0.0447,  0.0994,  0.0349],
#           [-0.0685,  0.1004,  0.1011],
#           [ 0.0720, -0.0338, -0.0510]]],
#
#
#         [[[ 0.0206, -0.0340, -0.0574],
#           [ 0.1230,  0.1654, -0.0191],
#           [-0.0431,  0.0028, -0.0115]],
#
#          [[ 0.0463,  0.0539, -0.1748],
#           [-0.0710,  0.1621,  0.0750],
#           [-0.0096, -0.1160, -0.1177]],
#
#          [[-0.1724, -0.0627,  0.0650],
#           [ 0.1227,  0.0889, -0.1701],
#           [-0.1157, -0.0304,  0.1862]]],
#
#
#         [[[ 0.0278, -0.0498,  0.0796],
#           [-0.0733, -0.1246,  0.1405],
#           [-0.0875, -0.0386, -0.1915]],
#
#          [[ 0.1288,  0.1458,  0.0701],
#           [-0.1342, -0.1899, -0.1563],
#           [ 0.1435,  0.0924,  0.1619]],
#
#          [[ 0.1008,  0.0487, -0.0019],
#           [-0.1464, -0.1649, -0.1800],
#           [ 0.0788, -0.0945, -0.0387]]],
#
#
#         [[[-0.1108, -0.0351, -0.1355],
#           [-0.1257,  0.0638, -0.0572],
#           [ 0.1188, -0.0617, -0.1412]],
#
#          [[-0.0340, -0.0933, -0.0589],
#           [-0.1832,  0.1077, -0.1340],
#           [ 0.0967,  0.0873,  0.1375]],
#
#          [[-0.1476,  0.1384, -0.0910],
#           [ 0.0714,  0.1807, -0.0271],
#           [-0.0015, -0.0443, -0.1607]]]])), ('bias', tensor([ 0.0924, -0.1910,  0.1195,  0.1440,  0.1820, -0.0454, -0.1581,  0.0433,
#          0.1063, -0.1915]))])

# %%
# Get shapes of weight and bias tensors within conv_layer
print(f"conv_layer weight shape: \n{conv_layer.weight.shape} -> [out_channels=10, in_channels=3, kernel_size=3]")
print(f"conv_layer bias shape: \n{conv_layer.bias.shape} -> [out_channels=10]")
# Out:
# conv_layer weight shape:
# torch.Size([10, 3, 3, 3]) -> [out_channels=10, in_channels=3, kernel_size=3]
# conv_layer bias shape:
# torch.Size([10]) -> [out_channels=10]

# %% [markdown]
# ## Stepping throught nn.MaxPool2d()

# %%
# Print out original image shape without and with unsqueezed dimension
print(f"Test iamge original shape: {test_image.shape}")
print(f"Test iamge with unsqueezed dimension: {test_image.unsqueeze(dim=0).shape}")

# Create a sample nn.MaxPool2d() layer
max_pool_layer = nn.MaxPool2d(kernel_size=2)

# Pass data through just the conv_layer
test_image_through_conv = conv_layer(test_image.unsqueeze(dim=0))
print(f"Shape after going through conv_layer(): {test_image_through_conv.shape}")

# Pass data through the max pool layer
test_image_through_conv_and_max_pool = max_pool_layer(test_image_through_conv)
print(f"Shape after going through conv_layer() and max_layer(): {test_image_through_conv_and_max_pool.shape}")
# Out:
# Test iamge original shape: torch.Size([3, 64, 64])
# Test iamge with unsqueezed dimension: torch.Size([1, 3, 64, 64])
# Shape after going through conv_layer(): torch.Size([1, 10, 62, 62])
# Shape after going through conv_layer() and max_layer(): torch.Size([1, 10, 31, 31])

# %%
torch.manual_seed(42)
# Create a random tensor with a similiar number of dimensions to our images
random_tensor = torch.randn(size=(1, 1, 2, 2))
print(f"Random tensor:\n{random_tensor}")
print(f"Random tensor shape: {random_tensor.shape}")

# Create a max pool layer
max_pool_layer = nn.MaxPool2d(kernel_size=2) # see what happens when you change the kernel_size value

# Pass the random tensor through the max pool layer
max_pool_tensor = max_pool_layer(random_tensor)
print(f"\nMax pool tensor:\n{max_pool_tensor} <- this is the maximum value from random_tensor")
print(f"Max pool tensor shape: {max_pool_tensor.shape}")
# Out:
# Random tensor:
# tensor([[[[0.3367, 0.1288],
#           [0.2345, 0.2303]]]])
# Random tensor shape: torch.Size([1, 1, 2, 2])
#
# Max pool tensor:
# tensor([[[[0.3367]]]]) <- this is the maximum value from random_tensor
# Max pool tensor shape: torch.Size([1, 1, 1, 1])

# %% [markdown]
# ### Setup a loss function and optimizer for model_2

# %%
# Setup loss and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(params=model_2.parameters(),
                            lr=0.1)

# %% [markdown]
# ### Training and testing model_2 using our training and test functions

# %%
torch.manual_seed(42)

# Measure time
from timeit import default_timer as timer
train_time_start_model_2 = timer()

# Train and test model
epochs = 3
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n----------")
    train_step(model=model_2,
               data_loader=train_dataloader,
               loss_fn=loss_fn,
               optimizer=optimizer,
               accuracy_fn=accuracy_fn,
               device=device)
    test_step(data_loader=test_dataloader,
              model=model_2,
              loss_fn=loss_fn,
              accuracy_fn=accuracy_fn,
              device=device)
    
train_time_end_model_2 = timer()
total_train_time_model_2 = print_train_time(start=train_time_start_model_2,
                                            end=train_time_end_model_2,
                                            device=device)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# ----------
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# ...
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00052 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00062 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00160 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00092 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00019 | Test accuracy: 0.32%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00059 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00105 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00156 | Test accuracy: 0.24%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00163 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00135 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00046 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00117 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00073 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00121 | Test accuracy: 0.25%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00070 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00066 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00099 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00133 | Test accuracy: 0.25%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00117 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00094 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00048 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00110 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00130 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00155 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00066 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00149 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00143 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00129 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00074 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00109 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00116 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00098 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00070 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00051 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00101 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00101 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00072 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00078 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00084 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00126 | Test accuracy: 0.24%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00120 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00103 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00065 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00068 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00072 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00152 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00118 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00119 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00055 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00054 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00093 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00058 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00064 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00097 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00028 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00053 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00075 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00069 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00136 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00093 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00097 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00067 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00055 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00082 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00074 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00119 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00084 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00100 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00088 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00104 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00135 | Test accuracy: 0.25%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00145 | Test accuracy: 0.25%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00160 | Test accuracy: 0.23%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00082 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00054 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00118 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00033 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00128 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00049 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00117 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00079 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00088 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00071 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00075 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00074 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00075 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00067 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00127 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00064 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00099 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00139 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00156 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00053 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00155 | Test accuracy: 0.25%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00230 | Test accuracy: 0.24%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00099 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00064 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00043 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00130 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00156 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00169 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00051 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00079 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00066 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00120 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00119 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00128 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00165 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00084 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00087 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00142 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00085 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00066 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00154 | Test accuracy: 0.23%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00053 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00040 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00108 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00176 | Test accuracy: 0.27%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00074 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00100 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00152 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00082 | Test accuracy: 0.28%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00083 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00116 | Test accuracy: 0.26%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00071 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00090 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00073 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00033 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00052 | Test accuracy: 0.30%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00103 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00069 | Test accuracy: 0.31%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00098 | Test accuracy: 0.29%
#
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# Test loss:0.00171 | Test accuracy: 0.24%
#
# torch.Size([16, 10, 14, 14])
# torch.Size([16, 10, 7, 7])
# torch.Size([16, 10])
# Test loss:0.00073 | Test accuracy: 0.30%
#
# Train time on cuda: 44.066 seconds

# %%
# Get model_2 results
model_2_result = eval_model(
    model=model_2,
    data_loader=test_dataloader,
    loss_fn=loss_fn,
    accuracy_fn=accuracy_fn
)
model_2_result
# Out:
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([16, 10, 14, 14])
# torch.Size([16, 10, 7, 7])
# torch.Size([16, 10])
# {'model_name': 'FashionMNISTModelV2',
#  'model_loss': 0.3212394714355469,
#  'model_acc': 88.12899361022365}

# %% [markdown]
# ### Compare model results and tarining time

# %%
import pandas as pd

compare_results = pd.DataFrame([model_0_result, model_1_results, model_2_result])
compare_results
# Out:
#             model_name  model_loss  model_acc
# 0  FashionMNISTModelV0    0.476639  83.426518
# 1  FashionMNISTModelV1    0.685001  75.019968
# 2  FashionMNISTModelV2    0.321239  88.128994

# %%
# Add training times to results comparison
compare_results["training_time"] = [total_train_time_model_0,
                                    total_train_time_model_1,
                                    total_train_time_model_2]
compare_results
# Out:
#             model_name  model_loss  model_acc  training_time
# 0  FashionMNISTModelV0    0.476639  83.426518      37.503752
# 1  FashionMNISTModelV1    0.685001  75.019968    3709.206292
# 2  FashionMNISTModelV2    0.321239  88.128994      44.066031

# %%
# Visualize our model results
compare_results.set_index("model_name")["model_acc"].plot(kind="barh")
plt.xlabel("accuracy (%)")
plt.ylabel("model")
# Out:
# Text(0, 0.5, 'model')

# %% [markdown]
# ## Make and evaluate random predictions with best model

# %%
def make_predictions(model: torch.nn.Module, data: list, device: torch.device = device):
    pred_probs = []
    model.eval()
    with torch.inference_mode():
        for sample in data:
            # Prepare sample
            sample = torch.unsqueeze(sample, dim=0).to(device) # Add an extra dimension and send sample to device

            # Forward pass (model outputs raw logit)
            pred_logit = model(sample)

            # Get prediction probability (logit -> prediction probability)
            pred_prob = torch.softmax(pred_logit.squeeze(), dim=0)

            # Get predprob off GPU for further calculations
            pred_probs.append(pred_prob.cpu())

        # Stack the pred_probs to turn list into a tensor
        return torch.stack(pred_probs)

# %%
import random
random.seed(42)
test_samples = []
test_labels = []
for sample, label in random.sample(list(test_data), k=9):
    test_samples.append(sample)
    test_labels.append(label)

# View the first test sample shape and label
print(f"Test sample image shape: {test_samples[0].shape}\nTest sample label: {test_labels[0]} ({class_names[test_labels[0]]})")
# Out:
# Test sample image shape: torch.Size([1, 28, 28])
# Test sample label: 5 (Sandal)

# %%
# Make predictions on test samples with model 2
pred_probs = make_predictions(model=model_2,
                              data=test_samples)

# View first two prediction probabilities list
pred_probs[:2]
# Out:
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# torch.Size([1, 10, 14, 14])
# torch.Size([1, 10, 7, 7])
# torch.Size([1, 10])
# tensor([[2.8398e-07, 7.0971e-08, 1.7239e-07, 7.1374e-07, 6.6671e-08, 9.9980e-01,
#          2.1100e-07, 5.6981e-05, 3.9733e-05, 9.7443e-05],
#         [1.6468e-01, 5.3630e-01, 1.5043e-03, 1.3491e-01, 2.6890e-02, 6.9285e-05,
#          1.3314e-01, 4.7028e-04, 1.9868e-03, 5.8474e-05]])

# %%
# Turn the prediction probabilities into prediction labels by taking the argmax()
pred_classes = pred_probs.argmax(dim=1)
pred_classes
# Out:
# tensor([5, 1, 7, 4, 3, 0, 4, 7, 1])

# %%
# Are our predictions in the same form as our test labels?
test_labels, pred_classes
# Out:
# ([5, 1, 7, 4, 3, 0, 4, 7, 1], tensor([5, 1, 7, 4, 3, 0, 4, 7, 1]))

# %%
# Plot predictions
plt.figure(figsize=(9,9))
nrows = 3
ncols = 3
for i, sample in enumerate(test_samples):
    # Create a subplot
    plt.subplot(nrows, ncols, i+1)

    # Plot the target image
    plt.imshow(sample.squeeze(), cmap="gray")

    # Find the prediction label (in text form, e.g. "Sandal")
    pred_label = class_names[pred_classes[i]]

    # Get the truth label (in text form, e.g. "T-shirt")
    truth_label = class_names[test_labels[i]]

    # Create the title text of the plot
    title_text = f"Pred: {pred_label} | Truth: {truth_label}"

    # CHeck for equality and change titile colour accordingly
    if pred_label == truth_label:
        plt.title(title_text, fontsize=10, c="g") # green text if correct
    else:
        plt.title(title_text, fontsize=10, c="r") # red text if wrong
    plt.axis(False)

# %% [markdown]
# ## Making a confusion matrix for further prediction evaluation

# %%
# Import tqdm for progress bar 
from tqdm.auto import tqdm

# 1. Make predictions with trained model
y_preds = []
model_2.eval()
with torch.inference_mode():
    for X, y in tqdm(test_dataloader, desc="Making predictions"):
        # Send data and targets to target device
        X, y = X.to(device), y.to(device)

        # Do the forward pass
        y_logit = model_2(X)

        # Turn predictions from logits -> predictions probabilities -> predictions labels
        y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)

        # Put predictions on CPU for evaluation
        y_preds.append(y_pred.cpu())

# Concatenate list of predictions into a tensor
y_pred_tensor = torch.cat(y_preds)
# Out:
# Making predictions:   0%|          | 0/313 [00:00<?, ?it/s]
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([16, 10, 14, 14])
# torch.Size([16, 10, 7, 7])
# torch.Size([16, 10])

# %%
import torchmetrics, mlxtend
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 import torchmetrics, mlxtend
#
# ModuleNotFoundError: No module named 'torchmetrics'

# %%
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix

# 2. Setup confusion matrix instance and compare predictions to targets
confmat = ConfusionMatrix(num_classes=len(class_names),
                          task="multiclass")
confmat_tensor = confmat(preds=y_pred_tensor,
                         target=test_data.targets)

# 3. Plot the confusion matrix
fig, ax = plot_confusion_matrix(
    conf_mat=confmat_tensor.numpy(), # matplotlib likes working with NumPy
    class_names=class_names, # turn the row and column labels into class names
    figsize=(10, 7)
)

# %% [markdown]
# ## Save and load best performing model

# %%
from pathlib import Path

# Create models directory (if it doesn't already exist)
MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True, # create parent directories if needed
                 exist_ok=True) # if models directory already exists, don't error

# Create model save path
MODEL_NAME = "03_pytorch_computer_vision_model_2.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# Save the model state dict
print(f"Saving model to: {MODEL_SAVE_PATH}")
torch.save(obj=model_2.state_dict(), # only saving the state_dict() only saves the learned parameters
           f=MODEL_SAVE_PATH)
# Out:
# Saving model to: models\03_pytorch_computer_vision_model_2.pth

# %%
# Create a new instance of FashionMNISTModelV2 (the same class as our saved state_dict())
# Note: loading model will error if the shapes here aren't the same as the saved version
loaded_model_2 = FashionMNISTModelV2(input_shape=1,
                                     hidden_units=10,
                                     outputshape=10)

# Load in the saved state_dict()
loaded_model_2.load_state_dict(torch.load(f=MODEL_SAVE_PATH))

# Send model to GPU
loaded_model_2 = loaded_model_2.to(device)

# %%
# Evaluate loaded model
torch.manual_seed(42)

loaded_model_2_results = eval_model(
    model=loaded_model_2,
    data_loader=test_dataloader,
    loss_fn=loss_fn,
    accuracy_fn=accuracy_fn
)

loaded_model_2_results
# Out:
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([32, 10, 14, 14])
# torch.Size([32, 10, 7, 7])
# torch.Size([32, 10])
# torch.Size([16, 10, 14, 14])
# torch.Size([16, 10, 7, 7])
# torch.Size([16, 10])
# {'model_name': 'FashionMNISTModelV2',
#  'model_loss': 0.3212394714355469,
#  'model_acc': 88.12899361022365}

# %%
model_2_result
# Out:
# {'model_name': 'FashionMNISTModelV2',
#  'model_loss': 0.3212394714355469,
#  'model_acc': 88.12899361022365}

# %%
# Check to see if results are cloase to each other (if they are very far away, there may be an error)
torch.isclose(torch.tensor(model_2_result["model_loss"]),
              torch.tensor(loaded_model_2_results["model_loss"]),
              atol=1e-08,
              rtol=0.0001)
# Out:
# tensor(True)
